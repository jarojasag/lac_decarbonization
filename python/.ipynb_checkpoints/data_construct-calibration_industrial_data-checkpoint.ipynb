# %%
import importlib
import inspect
import logging
import matplotlib.pyplot as plt
import model_attributes as ma
import model_afolu as mafl
import model_ippu as mi
import model_circular_economy as mc
import model_electricity as ml
import model_energy as me
import model_socioeconomic as se
import setup_analysis as sa
import support_functions as sf
import numpy as np
import os, os.path
import pandas as pd
import time
from typing import *
import warnings
# Out:
# /Users/jsyme/Documents/Projects/git_jbus/lac_decarbonization/python/model_attributes.py:2194: UserWarning: Invalid subsector attribute 'key_varreqs_partial'. Valid return type values are:'pycategory_primary', 'abv_subsector', 'sector', 'abv_sector', 'key_varreqs_all'
#   warnings.warn(f"Invalid subsector attribute '{return_type}'. Valid return type values are:{valid_rts}")

# %% [markdown]
# # Load general data
# - The following dataset gives some sector-level emissions that we cannot obtain elsewhere, notably chemicals and cement emissions
# - Article is accessible at https://essd.copernicus.org/articles/13/5213/2021/)
#
# Minx, J. C., Lamb, W. F., Andrew, R. M., Canadell, J. G., Crippa, M., Döbbeling, N., Forster, P. M., Guizzardi, D., Olivier, J., Peters, G. P., Pongratz, J., Reisinger, A., Rigby, M., Saunois, M., Smith, S. J., Solazzo, E., and Tian, H.: A comprehensive and synthetic dataset for global, regional, and national greenhouse gas emissions by sector 1970–2018 with an extension to 2019, Earth Syst. Sci. Data, 13, 5213–5252, https://doi.org/10.5194/essd-13-5213-2021, 2021.
#
# - The data itself (linked from above) can be accessed at https://zenodo.org/record/5566761#.ZBzAPC-B0bQ
# - The data include mappings to IPCC emission codes, and it could be used as part of a two part calibration or aggregate calibration (IPPU + INEN at the same time)

# %%
fp_essd_ghg_data = "/Users/jsyme/Documents/Projects/FY21/SWCHE131_1000/Data/Energy/essd_ghg_data.xlsx"
dict_essd = pd.read_excel(fp_essd_ghg_data, sheet_name = None);

importlib.reload(ma)
importlib.reload(sa)

# read data and set some fields

df_data = dict_essd.get("data")

field_country = "country"
field_description = "description"
field_gas = "gas"
field_ipcc = "IPCC_2006"
field_iso = "ISO"
field_title_sector = "sector_title"
field_title_subsector = "subsector_title"
field_value = "value"
field_year = "year"


##  SOME DATA REPLACEMENTS

# clean gas names
dict_repl = {
    "HFC-43-10-mee": "HFC-43-10mee",
    "c-C4F8": "cc4f8"
}
df_data[field_gas].replace(dict_repl, inplace = True)
# Out:
# /Users/jsyme/Documents/Projects/git_jbus/lac_decarbonization/python/model_attributes.py:2194: UserWarning: Invalid subsector attribute 'key_varreqs_partial'. Valid return type values are:'pycategory_primary', 'abv_subsector', 'sector', 'abv_sector', 'key_varreqs_all'
#   warnings.warn(f"Invalid subsector attribute '{return_type}'. Valid return type values are:{valid_rts}")

# %% [markdown]
# # CEMENT AND CHEMICAL DATA

# %%
importlib.reload(ma)
importlib.reload(sa)
# Out:
# /Users/jsyme/Documents/Projects/git_jbus/lac_decarbonization/python/model_attributes.py:2194: UserWarning: Invalid subsector attribute 'key_varreqs_partial'. Valid return type values are:'pycategory_primary', 'abv_subsector', 'sector', 'abv_sector', 'key_varreqs_all'
#   warnings.warn(f"Invalid subsector attribute '{return_type}'. Valid return type values are:{valid_rts}")
# <module 'setup_analysis' from '/Users/jsyme/Documents/Projects/git_jbus/lac_decarbonization/python/setup_analysis.py'>

# %%
df = dict_essd.get("sector_classification")
df[df["sector_title"] == "Buildings"]
# Out:
#     EDGAR_code fossil_bio sector_title  \
# 46        1A4a        bio    Buildings
# 47        1A4a     fossil    Buildings
# 48        1A4b        bio    Buildings
# 49        1A4b     fossil    Buildings
# 132        2F3     fossil    Buildings
# 133        2F4     fossil    Buildings
# 144       2F9a     fossil    Buildings
# 146       2F9c     fossil    Buildings
#
#                                 description          subsector_title IPCC_2006
# 46   Commercial and public services (biom.)          Non-residential   1.A.4.a
# 47    Commercial and public services (fos.)          Non-residential   1.A.4.a
# 48                      Residential (biom.)              Residential   1.A.4.b
# 49                       Residential (fos.)              Residential   1.A.4.b
# 132                      Fire Extinguishers  Non-CO2 (all buildings)     2.F.3
# 133                                Aerosols  Non-CO2 (all buildings)     2.F.4
# ...

# %%
if False:
    sf.pivot_df_clean(
        df_piv,
        [field_gas],
        [field_value]
    ).drop(["CO2", "CH4", "N2O"], axis = 1)

df_piv = df_data[#"Other (industry)", 
    df_data[field_title_subsector].isin(["Chemicals"]) &
    df_data[field_iso].isin(["BRA"]) &
    (df_data[field_year].isin(range(2000, 2020))) 
][[field_year, field_gas, field_value]]

df_piv = sf.simple_df_agg(
    df_piv,
    [field_year, field_gas],
    {field_value: "sum"}
)

df_piv
# Out:
#            value  year     gas
# 0   2.929985e+03  2000     CH4
# 1   2.728537e+07  2000     CO2
# 2   0.000000e+00  2000  HFC-23
# 3   2.544438e+04  2000     N2O
# 4   2.899512e+03  2001     CH4
# ..           ...   ...     ...
# 75  6.104875e+03  2018     N2O
# 76  2.894750e+03  2019     CH4
# 77  2.765005e+07  2019     CO2
# 78  0.000000e+00  2019  HFC-23
# 79  6.109369e+03  2019     N2O
#
# [80 rows x 3 columns]

# %%
df_data[#"Other (industry)", 
    df_data[field_title_subsector].isin(["Other (industry)"]) &
    df_data[field_gas].isin(["NF3"]) &
    (df_data[field_year].isin(range(2019, 2020))) 
]["country"].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Bulgaria', 'Belarus', 'Canada',
#        'Switzerland', 'China', 'Cyprus', 'Czech Republic', 'Germany',
#        'Denmark', 'Spain', 'Estonia', 'Finland', 'France',
#        'United Kingdom', 'Greece', 'Croatia', 'Hungary', 'Ireland',
#        'Iceland', 'Italy', 'Japan', 'Kazakhstan', 'Lithuania',
#        'Luxembourg', 'Latvia', 'Malta', 'Malaysia', 'Netherlands',
#        'Norway', 'New Zealand', 'Poland', 'Portugal', 'Romania',
#        'Russian Federation', 'Singapore', 'Slovak Republic', 'Slovenia',
#        'Sweden', 'Turkey', 'Taiwan, China', 'Ukraine', 'United States'],
#       dtype=object)

# %%
df_piv = df_data[#"Other (industry)", 
    df_data[field_title_subsector].isin(["Other (industry)"]) &
    df_data[field_iso].isin(["HND"]) &
    (df_data[field_year].isin(range(2000, 2020))) 
][[field_year, field_gas, field_value]]

df_piv = sf.simple_df_agg(
    df_piv,
    [field_year, field_gas],
    {field_value: "sum"}
)

sf.pivot_df_clean(
    df_piv,
    [field_gas],
    [field_value]
).drop(["CO2", "CH4", "N2O"], axis = 1).plot(x = "year")
# Out:
# /Users/jsyme/Documents/Projects/git_jbus/lac_decarbonization/python/support_functions.py:1223: FutureWarning: In a future version of pandas all arguments of pivot except for the argument 'data' will be keyword-only.
#   df_piv = pd.pivot(
# <AxesSubplot:xlabel='year'>

# %%
s_specified = set([x.lower() for x in df_data["gas"].unique()])

s_defined = sa.model_attributes.dict_attributes.get("emission_gas").table
s_defined = [x.lower() for x in list(set(s_defined["gas"]) | set(s_defined["emission_gas"]))]
s_defined = set(s_defined)

s_specified - s_defined
# Out:
# set()

# %%
#sorted(list(df_data["gas"].unique()))

# %%
df_data[
    #[str(x).lower() in(s_specified - s_defined) for x in list(df_data[field_gas])] & 
    (df_data[field_year] > 2018) &
    (df_data[field_iso].isin(["BRA"])) &
    (df_data[field_title_subsector].isin(["Other (industry)"]))
]

dict_repl = {
    "HFC-43-10-mee": "HFC-43-10mee",
    "c-C4F8": "cc4f8"
}
# Out:
#        ISO country                 region_ar6_6                region_ar6_10  \
# 73082  BRA  Brazil  Latin America and Caribbean  Latin America and Caribbean
# 73083  BRA  Brazil  Latin America and Caribbean  Latin America and Caribbean
# 73084  BRA  Brazil  Latin America and Caribbean  Latin America and Caribbean
# 73085  BRA  Brazil  Latin America and Caribbean  Latin America and Caribbean
# 73086  BRA  Brazil  Latin America and Caribbean  Latin America and Caribbean
# 73087  BRA  Brazil  Latin America and Caribbean  Latin America and Caribbean
# 73088  BRA  Brazil  Latin America and Caribbean  Latin America and Caribbean
# 73089  BRA  Brazil  Latin America and Caribbean  Latin America and Caribbean
# 73090  BRA  Brazil  Latin America and Caribbean  Latin America and Caribbean
# 73091  BRA  Brazil  Latin America and Caribbean  Latin America and Caribbean
# 73092  BRA  Brazil  Latin America and Caribbean  Latin America and Caribbean
# ...

# %%
df[df["subsector_title"].isin(["Oil and gas fugitive emissions"] )]
attr_gas = sa.model_attributes.dict_attributes.get("emission_gas").table
# Out:
#                             gas emission_gas  \
# 0          :math:`\text{CH}_4`           ch4
# 1          :math:`\text{CO}_2`           co2
# 2   :math:`\text{N}_2\text{O}`           n2o
# 3          :math:`\text{NF}_3`           nf3
# 4          :math:`\text{SF}_6`           sf6
# 5                      HFC-125         c2hf5
# 6                     HFC-134a       chf2cf3
# 7                     HFC-143a        c2h3f3
# 8                      HFC-152      ch2fch2f
# 9                     HFC-152a       ch3chf2
# 10                    HFC-227ea        c3hf7
# 11                      HFC-23          chf3
# 12                    HFC-236fa       c3h2f6
# 13                    HFC-245fa       c3h3f5
# 14                      HFC-32         ch2f2
# 15                   HFC-365mfc       c4h5f5
# 16                 HFC-43-10mee      c5h2f10
# 17                   PFC-C-1418         c5f8
# 18            Octafluorooxolane        c4f8o
# 19                     PFC-1114         c4f6
# ...
