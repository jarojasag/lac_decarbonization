# %%
import os, os.path
import numpy as np
import pandas as pd
import model_attributes as ma
from attribute_table import AttributeTable
import setup_analysis as sa
import support_classes as sc
import support_functions as sf
import importlib
import time
import warnings
import matplotlib.pyplot as plt
import geopandas as gpd
import rioxarray as rx
import itertools
import model_afolu as mafl

# %%
dir_data = "/Users/jsyme/Documents/Projects/FY21/SWCHE131_1000/Data/AFOLU"

# set names 
fn_climates = "kc_1984_2013.tif"
fn_countries = "WB_countries_Admin0_10m"
fn_cw = "values_info_with_cw_kc_1984_2013.csv"

fp_climates = os.path.join(dir_data, fn_climates)
fp_countries = os.path.join(dir_data, fn_countries, f"{fn_countries}.shp")
fp_cw = os.path.join(dir_data, fn_cw)

model_afolu = mafl.AFOLU(sa.model_attributes)
regions = sc.Regions(sa.model_attributes)
time_periods = sc.TimePeriods(sa.model_attributes)
# Out:
# /Users/jsyme/Documents/Projects/git_jbus/lac_decarbonization/python/model_attributes.py:2309: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   cols = list(set(attr_table.table.columns & set(fields_to_filter_on)))
# /Users/jsyme/Documents/Projects/git_jbus/lac_decarbonization/python/model_attributes.py:2309: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   cols = list(set(attr_table.table.columns & set(fields_to_filter_on)))
# /Users/jsyme/Documents/Projects/git_jbus/lac_decarbonization/python/model_attributes.py:2309: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   cols = list(set(attr_table.table.columns & set(fields_to_filter_on)))
# /Users/jsyme/Documents/Projects/git_jbus/lac_decarbonization/python/model_attributes.py:2309: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   cols = list(set(attr_table.table.columns & set(fields_to_filter_on)))
# /Users/jsyme/Documents/Projects/git_jbus/lac_decarbonization/python/support_functions.py:1210: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for i, df in df_in_grouped:

# %%
# convert geotiff to dataframe
rx_array = rx.open_rasterio(fp_climates)
df_climates = rx_array[0].to_pandas()
# retrieve climate categories
df_climate_cats = pd.read_csv(fp_cw, sep = "|")

# %%
def reshape_df_climate(
    df_input: pd.DataFrame,
    vec_x: np.ndarray,
    vec_y: np.ndarray,
    field_val: str = "value",
    field_x: str = "x",
    field_y: str = "y",
    flag_empty: int = flag_empty,
) -> pd.DataFrame:
    """
    Reshape df soils without having to melt and filter
    """
    arr = np.array(df_input)

    w = np.where(arr != flag_empty)
    
    # get indexing
    col_vals = arr[w[0], w[1]]
    col_x = vec_x[w[1]]
    col_y = vec_y[w[0]]
    
    df_out = pd.DataFrame(
        {
            field_x: col_x,
            field_y: col_y,
            field_val: col_vals
        }
    )
    
    return df_out



flag_empty = df_climates.iloc[0,0]
vec_x = np.array(df_climates.columns)
vec_y = np.array(df_climates.index)


dfc = reshape_df_climate(
    df_climates,
    vec_x,
    vec_y,
    flag_empty = flag_empty
)

crs_climates = "EPSG:4326"
gdf_climates_cut = dfc.copy()

# %%
#flag_empty = -3.4e+38
#np.where(np.array(df_climates.iloc[0:5, 0:5]) == )

# %%
"""
df_climates = df_climates.reset_index()#[-179.97083333333333].unique()
dfc = pd.melt(df_climates, ["y"]);
val = float(dfc["value"].iloc[0])
dfc = dfc[dfc["value"] != val].reset_index(drop = True)

# set some bounds
# http://bboxfinder.com/#-55.776573,-126.386719,33.431441,-33.398438
x_max = -34
x_min = -119
y_max = 33
y_min = -58
# filter out
dfc2 = dfc[
    (dfc["x"] <= x_max) & 
    (dfc["x"] >= x_min) & 
    (dfc["y"] <= y_max) & 
    (dfc["y"] >= y_min)
].reset_index(drop = True)

# create points with climates
gdf_climates = gpd.GeoDataFrame(
    dfc2, 
    geometry = gpd.points_from_xy(dfc2["x"], dfc2["y"])
)
gdf_climates.crs = "EPSG:4326"
gdf_climates_cut = gdf_climates.copy()
""";

# %%
# get countries 
countries_keep = regions.all_isos#list(sa.model_attributes.dict_attributes.get("region").table["category_name"])
gdf_world = gpd.read_file(fp_countries)

# some replacements
field_en = "ISO_A3"
gdf_world_red = gdf_world[gdf_world[field_en].isin(countries_keep)]
gdf_lac = gdf_world_red[[field_en, "geometry"]]
gdf_lac_bounds = gdf_lac.bounds

# %%
gdf_points = gdf_climates_cut[
    (gdf_climates_cut["x"] <= maxx) &
    (gdf_climates_cut["x"] >= minx) &
    (gdf_climates_cut["y"] <= maxy) &
    (gdf_climates_cut["y"] >= miny)
]

# %%
def df_to_gdf(
    df_in: pd.DataFrame,
    crs: str = crs_climates,
    field_x: str = "x",
    field_y: str = "y",
) -> gpd.GeoDataFrame:
    
    vec_x = np.array(df_in[field_x])
    vec_y = np.array(df_in[field_y])
    
    gdf_out = gpd.GeoDataFrame(
        df_in, 
        geometry = [shapely.geometry.Point(*x) for x in zip(vec_x, vec_y)]
    )
    gdf_out.crs = crs
    
    return gdf_out
    
t0 = time.time()
gdf_points2 = df_to_gdf(gdf_points)
sf.get_time_elapsed(t0)
# Out:
# 58.58

# %%
#sf.get_time_elapsed(t0)
import shapely
type(gdf_points2.iloc[0]["geometry"])

vec_x = np.array(gdf_points["x"])[0:100000]
vec_y = np.array(gdf_points["y"])[0:100000]

t0 = time.time()
xx = [shapely.geometry.Point(*x) for x in zip(vec_x, vec_y)]
print(sf.get_time_elapsed(t0))

t0 = time.time()
xx2 = gpd.points_from_xy(vec_x, vec_y, crs = crs_climates)
print(sf.get_time_elapsed(t0))
# Out:
# 0.68
# 2.08

# %%
i = 0
sep = "---"*25
print("Copying climate gdf...\n\n")
#gdf_climates_cut = gdf_climates.copy()


df_out = []
df_agg_out = []
t0 = time.time()
list_times = [t0]
n = len(gdf_lac_bounds)

while i < n:
    
    # country
    gdf_country = gdf_lac.iloc[i:(i + 1)]
    bounds = gdf_lac_bounds.iloc[i:(i + 1)]

    country = str(gdf_country[field_en].iloc[0])
    maxx = float(bounds["maxx"].iloc[0])
    minx = float(bounds["minx"].iloc[0])
    maxy = float(bounds["maxy"].iloc[0])
    miny = float(bounds["miny"].iloc[0])
    
    pos = i + 1
    print(f"Starting country {country}\n{sep} ({pos}/{n})\n")
    
    # get points
    print("Filtering points...\n")
    gdf_points = gdf_climates_cut[
        (gdf_climates_cut["x"] <= maxx) &
        (gdf_climates_cut["x"] >= minx) &
        (gdf_climates_cut["y"] <= maxy) &
        (gdf_climates_cut["y"] >= miny)
    ]
    
    gdf_points = gpd.GeoDataFrame(
        gdf_points,
        geometry = gpd.points_from_xy(gdf_points["x"], gdf_points["y"], crs = crs_climates)
    )
    
    print(f"Merging points within bbox x = ({minx}, {maxx}), y = ({miny}, {maxy}) to country...\n")
    gdf_join = gpd.sjoin(
        gdf_country, 
        gdf_points[["value", "geometry"]].rename(columns = {"value": "kcc"}),
        how = "inner"
    ).drop("geometry", axis = 1)
    
    
    print(f"Aggregating counts by climate...\n")
    gdf_agg = gdf_join[[field_en, "kcc"]].copy()
    gdf_agg["count"] = 1
    gdf_agg = (
        gdf_agg[[field_en, "kcc", "count"]]
        .groupby([field_en, "kcc"])
        .agg(
            {field_en: "first", "kcc": "first", "count": "sum"}
        )
        .reset_index(drop = True)
    )

    
    print("Appending output...")
    df_out.append(gdf_join)
    df_agg_out.append(gdf_agg)
    
    
    print("Dropping indices...")
    indices_to_drop = list(gdf_join["index_right"])
    gdf_climates_cut.drop(indices_to_drop, axis = 0, inplace = True)
    
    
    i += 1
    list_times.append(time.time())
    t_delta = np.round(list_times[i] - list_times[i - 1], 2)
    t_elapsed = np.round(list_times[i] - list_times[0])
    
    print(f"\n{sep}\n\nCountry {country} complete in {t_delta} seconds ({t_elapsed} seconds overall)\n\n{sep}\n\n\n")
# Out:
# Copying climate gdf...
#
#
# Starting country IDN
# --------------------------------------------------------------------------- (1/216)
#
# Filtering points...
#
# Merging points within bbox x = (95.01270592493853, 140.97762699419047), y = (-10.92262135219363, 5.910101630386009) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country IDN complete in 155.7 seconds (156.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country MYS
# --------------------------------------------------------------------------- (2/216)
#
# Filtering points...
#
# Merging points within bbox x = (99.64522806022688, 119.2780867853769), y = (0.8513703412683071, 7.355780340990009) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country MYS complete in 148.74 seconds (304.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country CHL
# --------------------------------------------------------------------------- (3/216)
#
# Filtering points...
#
# Merging points within bbox x = (-109.45372473890552, -66.42080644356247), y = (-55.918504222591764, -17.50658819768711) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country CHL complete in 314.26 seconds (619.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country BOL
# --------------------------------------------------------------------------- (4/216)
#
# Filtering points...
#
# Merging points within bbox x = (-69.66649226960254, -57.46566076733052), y = (-22.897257587567594, -9.679821471783441) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country BOL complete in 262.01 seconds (881.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country PER
# --------------------------------------------------------------------------- (5/216)
#
# Filtering points...
#
# Merging points within bbox x = (-81.33755752885685, -68.6842524826659), y = (-18.337746206622114, -0.029092711959037842) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country PER complete in 250.38 seconds (1131.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country ARG
# --------------------------------------------------------------------------- (6/216)
#
# Filtering points...
#
# Merging points within bbox x = (-73.58803584877535, -53.66155188041489), y = (-55.05201588302651, -21.786937764066522) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country ARG complete in 433.2 seconds (1564.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country CYP
# --------------------------------------------------------------------------- (7/216)
#
# Filtering points...
#
# Merging points within bbox x = (32.271739128757815, 34.59253990978908), y = (34.56854889521537, 35.69196198076088) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country CYP complete in 147.81 seconds (1712.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country IND
# --------------------------------------------------------------------------- (8/216)
#
# Filtering points...
#
# Merging points within bbox x = (68.14340253989536, 97.13477339697477), y = (6.745550847993286, 35.64779937773915) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country IND complete in 533.12 seconds (2245.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country CHN
# --------------------------------------------------------------------------- (9/216)
#
# Filtering points...
#
# Merging points within bbox x = (73.60225630688313, 134.7725793871291), y = (18.169338282735623, 53.569444478579896) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country CHN complete in 1537.41 seconds (3783.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country ISR
# --------------------------------------------------------------------------- (10/216)
#
# Filtering points...
#
# Merging points within bbox x = (34.248350857406194, 35.65005090332659), y = (29.489691472983168, 33.28212982173392) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country ISR complete in 2590.11 seconds (6373.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country LBN
# --------------------------------------------------------------------------- (11/216)
#
# Filtering points...
#
# Merging points within bbox x = (35.09961998797212, 36.604101196113334), y = (33.05558034155956, 34.68754791320566) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country LBN complete in 53.47 seconds (6426.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country ETH
# --------------------------------------------------------------------------- (12/216)
#
# Filtering points...
#
# Merging points within bbox x = (32.98979984508685, 47.97916914863737), y = (3.403333434790227, 14.87953216587681) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country ETH complete in 156.25 seconds (6582.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country SSD
# --------------------------------------------------------------------------- (13/216)
#
# Filtering points...
#
# Merging points within bbox x = (24.12155562309357, 35.92083540892702), y = (3.4902015178857937, 12.216154683791672) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country SSD complete in 123.47 seconds (6706.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country SOM
# --------------------------------------------------------------------------- (14/216)
#
# Filtering points...
#
# Merging points within bbox x = (40.96538537593443, 51.41703781074642), y = (-1.696302993288441, 11.989118646108693) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country SOM complete in 96.73 seconds (6803.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country KEN
# --------------------------------------------------------------------------- (15/216)
#
# Filtering points...
#
# Merging points within bbox x = (33.890468384008784, 41.88501916530231), y = (-4.677504165384903, 4.620158386300545) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country KEN complete in 94.06 seconds (6897.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country PAK
# --------------------------------------------------------------------------- (16/216)
#
# Filtering points...
#
# Merging points within bbox x = (60.84437870291487, 77.04897098842042), y = (23.694525458383225, 37.05448354108262) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country PAK complete in 154.2 seconds (7051.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country MWI
# --------------------------------------------------------------------------- (17/216)
#
# Filtering points...
#
# Merging points within bbox x = (32.66330814655379, 35.90429895033634), y = (-17.135335388317458, -9.381235046560107) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country MWI complete in 67.83 seconds (7119.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country TZA
# --------------------------------------------------------------------------- (18/216)
#
# Filtering points...
#
# Merging points within bbox x = (29.321031534577685, 40.44939212324795), y = (-11.731272482439067, -0.9858301799188212) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country TZA complete in 113.64 seconds (7232.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country SYR
# --------------------------------------------------------------------------- (19/216)
#
# Filtering points...
#
# Merging points within bbox x = (35.57077925595797, 42.37718550630615), y = (32.31304168712421, 37.32490631057783) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country SYR complete in 68.81 seconds (7301.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country SUR
# --------------------------------------------------------------------------- (20/216)
#
# Filtering points...
#
# Merging points within bbox x = (-58.06769120328636, -53.98635745443295), y = (1.8335067754173906, 6.011573766416234) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country SUR complete in 61.48 seconds (7363.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country GUY
# --------------------------------------------------------------------------- (21/216)
#
# Filtering points...
#
# Merging points within bbox x = (-61.3967128092487, -56.48181901083865), y = (1.185820210734164, 8.558010158142338) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country GUY complete in 68.64 seconds (7431.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country KOR
# --------------------------------------------------------------------------- (22/216)
#
# Filtering points...
#
# Merging points within bbox x = (124.61361738443486, 131.86252188597632), y = (33.19757721591583, 38.624335028039184) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country KOR complete in 57.75 seconds (7489.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country PRK
# --------------------------------------------------------------------------- (23/216)
#
# Filtering points...
#
# Merging points within bbox x = (124.21131598864201, 130.69996178480858), y = (37.6756045588034, 43.010269877852636) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country PRK complete in 58.43 seconds (7547.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country MAR
# --------------------------------------------------------------------------- (24/216)
#
# Filtering points...
#
# Merging points within bbox x = (-13.178254487854304, -1.031999470798894), y = (27.661439311375148, 35.92651914943923) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country MAR complete in 86.61 seconds (7634.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country CRI
# --------------------------------------------------------------------------- (25/216)
#
# Filtering points...
#
# Merging points within bbox x = (-87.11766516831284, -82.56283687382262), y = (5.5150820982602795, 11.209937032168341) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country CRI complete in 53.67 seconds (7688.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country NIC
# --------------------------------------------------------------------------- (26/216)
#
# Filtering points...
#
# Merging points within bbox x = (-87.68582109256931, -82.72569739461903), y = (10.713481547335618, 15.030969950402948) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country NIC complete in 63.47 seconds (7751.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country COG
# --------------------------------------------------------------------------- (27/216)
#
# Filtering points...
#
# Merging points within bbox x = (11.114016304109214, 18.642406859988625), y = (-5.0196308357943735, 3.7082760622905084) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country COG complete in 98.5 seconds (7850.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country COD
# --------------------------------------------------------------------------- (28/216)
#
# Filtering points...
#
# Merging points within bbox x = (12.210541211807538, 31.280446818266114), y = (-13.458350523557783, 5.375280253181188) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country COD complete in 260.43 seconds (8110.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country BTN
# --------------------------------------------------------------------------- (29/216)
#
# Filtering points...
#
# Merging points within bbox x = (88.7300667722638, 92.0887764891437), y = (26.69614939417926, 28.35839893056624) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country BTN complete in 62.03 seconds (8172.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country UKR
# --------------------------------------------------------------------------- (30/216)
#
# Filtering points...
#
# Merging points within bbox x = (22.13283980301452, 40.15954309104086), y = (44.38104889539028, 52.368949280085246) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country UKR complete in 128.0 seconds (8300.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country BLR
# --------------------------------------------------------------------------- (31/216)
#
# Filtering points...
#
# Merging points within bbox x = (23.165644979232468, 32.71953210432321), y = (51.235168355835015, 56.15680592925031) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country BLR complete in 87.45 seconds (8388.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country NAM
# --------------------------------------------------------------------------- (32/216)
#
# Filtering points...
#
# Merging points within bbox x = (11.717621290190436, 25.25978072080369), y = (-28.95936818429425, -16.951057230606636) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country NAM complete in 149.05 seconds (8537.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country ZAF
# --------------------------------------------------------------------------- (33/216)
#
# Filtering points...
#
# Merging points within bbox x = (16.469981315785162, 37.97779381563214), y = (-46.96575286270439, -22.12645192461656) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country ZAF complete in 160.56 seconds (8697.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country MAF
# --------------------------------------------------------------------------- (34/216)
#
# Filtering points...
#
# Merging points within bbox x = (-63.14683997258663, -63.01073157480232), y = (18.033391472438552, 18.122137761748377) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country MAF complete in 52.07 seconds (8749.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country SXM
# --------------------------------------------------------------------------- (35/216)
#
# Filtering points...
#
# Merging points within bbox x = (-63.11888587058644, -63.017568585221966), y = (18.019110419110575, 18.06211985924415) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country SXM complete in 48.75 seconds (8798.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country OMN
# --------------------------------------------------------------------------- (36/216)
#
# Filtering points...
#
# Merging points within bbox x = (51.978614949620294, 59.844574415377), y = (16.642401433879115, 26.3859723976081) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country OMN complete in 76.14 seconds (8874.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country UZB
# --------------------------------------------------------------------------- (37/216)
#
# Filtering points...
#
# Merging points within bbox x = (55.975838663423644, 73.14864058439554), y = (37.18514740003252, 45.55871897390159) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country UZB complete in 151.05 seconds (9025.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country KAZ
# --------------------------------------------------------------------------- (38/216)
#
# Filtering points...
#
# Merging points within bbox x = (46.47827884888983, 87.32379602096967), y = (40.584655660130636, 55.434550273076695) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country KAZ complete in 398.96 seconds (9424.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country TJK
# --------------------------------------------------------------------------- (39/216)
#
# Filtering points...
#
# Merging points within bbox x = (67.34269006259638, 75.16412479712176), y = (36.67864084919586, 41.03997670496102) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country TJK complete in 92.87 seconds (9517.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country LTU
# --------------------------------------------------------------------------- (40/216)
#
# Filtering points...
#
# Merging points within bbox x = (20.9245687000855, 26.800720255835188), y = (53.886841126416925, 56.44260243735266) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country LTU complete in 53.77 seconds (9571.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country BRA
# --------------------------------------------------------------------------- (41/216)
#
# Filtering points...
#
# Merging points within bbox x = (-74.0184746913539, -28.87706458236454), y = (-33.74228037503923, 5.267224833359421) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country BRA complete in 617.18 seconds (10188.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country URY
# --------------------------------------------------------------------------- (42/216)
#
# Filtering points...
#
# Merging points within bbox x = (-58.439361131710825, -53.110836141674554), y = (-34.973402601848534, -30.096869811592512) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country URY complete in 100.28 seconds (10288.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country MNG
# --------------------------------------------------------------------------- (43/216)
#
# Filtering points...
#
# Merging points within bbox x = (87.73570886267396, 119.90702681473579), y = (41.58614491835334, 52.129584046166826) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country MNG complete in 209.33 seconds (10498.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country RUS
# --------------------------------------------------------------------------- (44/216)
#
# Filtering points...
#
# Merging points within bbox x = (-179.99999999990004, 180.00000000010004), y = (41.192680562258204, 81.85871002774564) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country RUS complete in 6113.74 seconds (16611.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country CZE
# --------------------------------------------------------------------------- (45/216)
#
# Filtering points...
#
# Merging points within bbox x = (12.07614099081411, 18.837433715693464), y = (48.55791575191046, 51.04001230892095) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country CZE complete in 468.27 seconds (17080.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country DEU
# --------------------------------------------------------------------------- (46/216)
#
# Filtering points...
#
# Merging points within bbox x = (5.852489867613372, 15.02205936684635), y = (47.27112091110121, 55.06533437688006) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country DEU complete in 71.44 seconds (17151.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country EST
# --------------------------------------------------------------------------- (47/216)
#
# Filtering points...
#
# Merging points within bbox x = (21.83236738434738, 28.186475463971533), y = (57.51581858316115, 59.670884506714685) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country EST complete in 40.23 seconds (17191.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country LVA
# --------------------------------------------------------------------------- (48/216)
#
# Filtering points...
#
# Merging points within bbox x = (20.968597851809477, 28.21727461712993), y = (55.6669908657359, 58.07513844888035) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country LVA complete in 41.03 seconds (17232.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country SWE
# --------------------------------------------------------------------------- (49/216)
#
# Filtering points...
#
# Merging points within bbox x = (11.108164910182495, 24.16341353440714), y = (55.3426781273937, 69.03635569336063) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country SWE complete in 107.58 seconds (17340.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country FIN
# --------------------------------------------------------------------------- (50/216)
#
# Filtering points...
#
# Merging points within bbox x = (19.513194207146967, 31.569524779844755), y = (59.811224676977304, 70.07531036358245) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country FIN complete in 93.95 seconds (17434.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country VNM
# --------------------------------------------------------------------------- (51/216)
#
# Filtering points...
#
# Merging points within bbox x = (102.11865523275287, 109.47242272183121), y = (8.565578517934284, 23.366275126595895) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country VNM complete in 82.76 seconds (17517.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country KHM
# --------------------------------------------------------------------------- (52/216)
#
# Filtering points...
#
# Merging points within bbox x = (102.31342370603926, 107.61051639861296), y = (10.415773620356333, 14.704581604657392) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country KHM complete in 3134.94 seconds (20652.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country LUX
# --------------------------------------------------------------------------- (53/216)
#
# Filtering points...
#
# Merging points within bbox x = (5.714927204926596, 6.502579386629463), y = (49.44132436182991, 50.174974671144184) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country LUX complete in 42.48 seconds (20694.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country ARE
# --------------------------------------------------------------------------- (54/216)
#
# Filtering points...
#
# Merging points within bbox x = (51.56934655000333, 56.383636915211525), y = (22.620945943300683, 26.074791971672198) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country ARE complete in 45.14 seconds (20739.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country BEL
# --------------------------------------------------------------------------- (55/216)
#
# Filtering points...
#
# Merging points within bbox x = (2.5217999275246825, 6.374525186688061), y = (49.49522288143089, 51.49623769131648) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country BEL complete in 38.67 seconds (20778.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country GEO
# --------------------------------------------------------------------------- (56/216)
#
# Filtering points...
#
# Merging points within bbox x = (39.98597635532457, 46.6948031005827), y = (41.044110820058336, 43.57584259036332) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country GEO complete in 39.33 seconds (20817.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country MKD
# --------------------------------------------------------------------------- (57/216)
#
# Filtering points...
#
# Merging points within bbox x = (20.444157348982515, 23.00958215319389), y = (40.84939402271601, 42.37033477942657) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country MKD complete in 36.98 seconds (20854.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country ALB
# --------------------------------------------------------------------------- (58/216)
#
# Filtering points...
#
# Merging points within bbox x = (19.272032510891734, 21.036679321293718), y = (39.63701324466558, 42.65481353791449) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country ALB complete in 35.94 seconds (20890.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country AZE
# --------------------------------------------------------------------------- (59/216)
#
# Filtering points...
#
# Merging points within bbox x = (44.774558553034865, 50.62574303481324), y = (38.392644755051435, 41.89044158980755) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country AZE complete in 46.39 seconds (20937.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country TUR
# --------------------------------------------------------------------------- (60/216)
#
# Filtering points...
#
# Merging points within bbox x = (25.663259311168304, 44.806992829255705), y = (35.81977854474411, 42.09878164305843) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country TUR complete in 100.77 seconds (21037.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country ESP
# --------------------------------------------------------------------------- (61/216)
#
# Filtering points...
#
# Merging points within bbox x = (-18.16722571479488, 4.337087436436093), y = (27.64223867417553, 43.7934431012182) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country ESP complete in 132.43 seconds (21170.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country LAO
# --------------------------------------------------------------------------- (62/216)
#
# Filtering points...
#
# Merging points within bbox x = (100.09707320196674, 107.66436323957191), y = (13.915456644608525, 22.49604400742504) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country LAO complete in 72.99 seconds (21243.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country KGZ
# --------------------------------------------------------------------------- (63/216)
#
# Filtering points...
#
# Merging points within bbox x = (69.22629602044503, 80.25756066859003), y = (39.18923695871871, 43.261701557580864) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country KGZ complete in 48.77 seconds (21291.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country ARM
# --------------------------------------------------------------------------- (64/216)
#
# Filtering points...
#
# Merging points within bbox x = (43.436293986278486, 46.6026123457832), y = (38.86370127369486, 41.29045237297868) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country ARM complete in 38.42 seconds (21330.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country DNK
# --------------------------------------------------------------------------- (65/216)
#
# Filtering points...
#
# Merging points within bbox x = (8.094004754216087, 15.151377800445175), y = (54.5685895846417, 57.75116608324822) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country DNK complete in 38.8 seconds (21369.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country LBY
# --------------------------------------------------------------------------- (66/216)
#
# Filtering points...
#
# Merging points within bbox x = (9.286543823238901, 25.156260612637197), y = (19.49612375900432, 33.1812253152961) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country LBY complete in 171.63 seconds (21540.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country TUN
# --------------------------------------------------------------------------- (67/216)
#
# Filtering points...
#
# Merging points within bbox x = (7.479832397747032, 11.564130900220903), y = (30.228905334713488, 37.34520091369126) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country TUN complete in 58.14 seconds (21598.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country ROU
# --------------------------------------------------------------------------- (68/216)
#
# Filtering points...
#
# Merging points within bbox x = (20.24282596874349, 29.699554884250574), y = (43.650049948446394, 48.27483225560417) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country ROU complete in 66.63 seconds (21665.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country HUN
# --------------------------------------------------------------------------- (69/216)
#
# Filtering points...
#
# Merging points within bbox x = (16.094035278305512, 22.87760054642814), y = (45.74134348611307, 48.569232889786065) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country HUN complete in 46.84 seconds (21712.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country SVK
# --------------------------------------------------------------------------- (70/216)
#
# Filtering points...
#
# Merging points within bbox x = (16.844480427729593, 22.539636677690567), y = (47.750006408568936, 49.60177968358556) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country SVK complete in 37.81 seconds (21750.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country POL
# --------------------------------------------------------------------------- (71/216)
#
# Filtering points...
#
# Merging points within bbox x = (14.123922972567186, 24.14315637186911), y = (48.994013163876446, 54.838324286436716) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country POL complete in 65.06 seconds (21815.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country IRL
# --------------------------------------------------------------------------- (72/216)
#
# Filtering points...
#
# Merging points within bbox x = (-10.478179490690877, -5.993519661203379), y = (51.44570547083089, 55.38637929906548) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country IRL complete in 44.54 seconds (21859.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country GBR
# --------------------------------------------------------------------------- (73/216)
#
# Filtering points...
#
# Merging points within bbox x = (-13.691314257247143, 1.7711694673970442), y = (49.909613348177515, 60.847886459992196) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country GBR complete in 55.5 seconds (21915.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country GRC
# --------------------------------------------------------------------------- (74/216)
#
# Filtering points...
#
# Merging points within bbox x = (19.626475456976834, 28.239756706906576), y = (34.81500885557426, 41.75047597278797) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country GRC complete in 53.17 seconds (21968.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country ZMB
# --------------------------------------------------------------------------- (75/216)
#
# Filtering points...
#
# Merging points within bbox x = (21.979877563298942, 33.674202514734304), y = (-18.069231872253056, -8.194124042590431) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country ZMB complete in 102.77 seconds (22071.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country SLE
# --------------------------------------------------------------------------- (76/216)
#
# Filtering points...
#
# Merging points within bbox x = (-13.301096157861366, -10.282235879582117), y = (6.919419664186194, 9.99600596140607) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country SLE complete in 43.98 seconds (22115.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country GIN
# --------------------------------------------------------------------------- (77/216)
#
# Filtering points...
#
# Merging points within bbox x = (-15.08112545457601, -7.662447469575), y = (7.190208232024361, 12.673387757439116) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country GIN complete in 52.56 seconds (22167.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country LBR
# --------------------------------------------------------------------------- (78/216)
#
# Filtering points...
#
# Merging points within bbox x = (-11.476185676427804, -7.384118205091056), y = (4.347235418779576, 8.565395609319978) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country LBR complete in 42.51 seconds (22210.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country CAF
# --------------------------------------------------------------------------- (79/216)
#
# Filtering points...
#
# Merging points within bbox x = (14.387266072071611, 27.441301310307267), y = (2.236453755836237, 11.00082834904913) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country CAF complete in 92.57 seconds (22302.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country SDN
# --------------------------------------------------------------------------- (80/216)
#
# Filtering points...
#
# Merging points within bbox x = (21.80944868990514, 38.60385175885165), y = (8.681641744071271, 22.22696482326802) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country SDN complete in 165.42 seconds (22468.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country DJI
# --------------------------------------------------------------------------- (81/216)
#
# Filtering points...
#
# Merging points within bbox x = (41.74911014811488, 43.41871178522075), y = (10.929824930975826, 12.70791250236016) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country DJI complete in 46.95 seconds (22515.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country ERI
# --------------------------------------------------------------------------- (82/216)
#
# Filtering points...
#
# Merging points within bbox x = (36.42364709513737, 43.12387128992816), y = (12.360021871012577, 18.004828192167395) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country ERI complete in 42.42 seconds (22557.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country AUT
# --------------------------------------------------------------------------- (83/216)
#
# Filtering points...
#
# Merging points within bbox x = (9.521154825334975, 17.14833784961212), y = (46.378643087108856, 49.00977447521194) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country AUT complete in 38.5 seconds (22596.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country IRQ
# --------------------------------------------------------------------------- (84/216)
#
# Filtering points...
#
# Merging points within bbox x = (38.77451135241705, 48.55925540541267), y = (29.063136698899598, 37.3754975382808) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country IRQ complete in 87.45 seconds (22683.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country ITA
# --------------------------------------------------------------------------- (85/216)
#
# Filtering points...
#
# Merging points within bbox x = (6.602728312361762, 18.517425977127175), y = (35.489243881899654, 47.08521494541344) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country ITA complete in 71.25 seconds (22754.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country CHE
# --------------------------------------------------------------------------- (86/216)
#
# Filtering points...
#
# Merging points within bbox x = (5.954809203681862, 10.466626831363214), y = (45.820718486269186, 47.80116607705287) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country CHE complete in 37.36 seconds (22792.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country IRN
# --------------------------------------------------------------------------- (87/216)
#
# Filtering points...
#
# ...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country BMU complete in 1.28 seconds (33267.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country MUS
# --------------------------------------------------------------------------- (189/216)
#
# Filtering points...
#
# Merging points within bbox x = (56.524180534604056, 63.4939070967352), y = (-20.517347915373932, -10.323907159088094) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country MUS complete in 1.36 seconds (33268.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country COM
# --------------------------------------------------------------------------- (190/216)
#
# Filtering points...
#
# Merging points within bbox x = (43.21322675930753, 44.52906334669615), y = (-12.380303644197795, -11.36126067543978) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country COM complete in 1.4 seconds (33270.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country STP
# --------------------------------------------------------------------------- (191/216)
#
# Filtering points...
#
# Merging points within bbox x = (6.461680534828872, 7.462738477298956), y = (0.024115301879703566, 1.6997744809075925) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country STP complete in 1.31 seconds (33271.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country CPV
# --------------------------------------------------------------------------- (192/216)
#
# Filtering points...
#
# Merging points within bbox x = (-25.360422330026438, -22.666574673981984), y = (14.803941147765784, 17.196600653397468) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country CPV complete in 1.62 seconds (33272.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country MLT
# --------------------------------------------------------------------------- (193/216)
#
# Filtering points...
#
# Merging points within bbox x = (14.183604363150891, 14.567149285211372), y = (35.80121491083952, 36.07558828337261) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country MLT complete in 1.38 seconds (33274.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country IMN
# --------------------------------------------------------------------------- (194/216)
#
# Filtering points...
#
# Merging points within bbox x = (-4.790150519930478, -4.311919726214342), y = (54.05695221627184, 54.41901276182955) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country IMN complete in 1.3 seconds (33275.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country FRO
# --------------------------------------------------------------------------- (195/216)
#
# Filtering points...
#
# Merging points within bbox x = (-7.644154426385626, -6.275786913035574), y = (61.394110418760874, 62.398911851300966) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country FRO complete in 1.55 seconds (33277.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country SGP
# --------------------------------------------------------------------------- (196/216)
#
# Filtering points...
#
# Merging points within bbox x = (103.64039147218875, 104.0034285816638), y = (1.2643089856712209, 1.4486351581860504) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country SGP complete in 1.36 seconds (33278.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country TON
# --------------------------------------------------------------------------- (197/216)
#
# Filtering points...
#
# Merging points within bbox x = (-176.2193090489734, -173.91425533761372), y = (-22.33879973821729, -15.559502862966724) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country TON complete in 1.32 seconds (33279.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country WSM
# --------------------------------------------------------------------------- (198/216)
#
# Filtering points...
#
# Merging points within bbox x = (-172.7825821607381, -171.43769283795407), y = (-14.0528296850419, -13.462823174949506) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country WSM complete in 1.5 seconds (33281.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country SLB
# --------------------------------------------------------------------------- (199/216)
#
# Filtering points...
#
# Merging points within bbox x = (155.50798587324948, 168.8258569666258), y = (-12.290622654411948, -6.599867446425492) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country SLB complete in 3.16 seconds (33284.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country TUV
# --------------------------------------------------------------------------- (200/216)
#
# Filtering points...
#
# Merging points within bbox x = (176.12525475430357, 179.9067488942461), y = (-9.42066822735677, -5.6775041651850415) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country TUV complete in 1.46 seconds (33285.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country MDV
# --------------------------------------------------------------------------- (201/216)
#
# Filtering points...
#
# Merging points within bbox x = (72.68482506602402, 73.75318444110911), y = (-0.6885718725937977, 7.107245184217902) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country MDV complete in 1.38 seconds (33287.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country NRU
# --------------------------------------------------------------------------- (202/216)
#
# Filtering points...
#
# Merging points within bbox x = (166.90699303490067, 166.9582625663644), y = (-0.5518531229232622, -0.4904110657180354) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country NRU complete in 1.26 seconds (33288.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country FSM
# --------------------------------------------------------------------------- (203/216)
#
# Filtering points...
#
# Merging points within bbox x = (138.06381269569943, 163.04656009207463), y = (0.9181582699882256, 9.775580144907792) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country FSM complete in 1.35 seconds (33289.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country VUT
# --------------------------------------------------------------------------- (204/216)
#
# Filtering points...
#
# Merging points within bbox x = (166.52051842468563, 169.89893639389948), y = (-20.253106377857023, -13.064873955568544) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country VUT complete in 2.08 seconds (33292.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country ASM
# --------------------------------------------------------------------------- (205/216)
#
# Filtering points...
#
# Merging points within bbox x = (-171.08653723860266, -168.1604711584172), y = (-14.532891534416706, -11.051364842013811) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country ASM complete in 1.33 seconds (33293.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country PLW
# --------------------------------------------------------------------------- (206/216)
#
# Filtering points...
#
# Merging points within bbox x = (131.13111412881403, 134.72734299088643), y = (2.949042058843986, 8.096617828849787) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country PLW complete in 1.31 seconds (33294.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country GUM
# --------------------------------------------------------------------------- (207/216)
#
# Filtering points...
#
# Merging points within bbox x = (144.62419681073425, 144.95215905010014), y = (13.24103424723279, 13.654120184399062) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country GUM complete in 1.28 seconds (33295.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country MNP
# --------------------------------------------------------------------------- (208/216)
#
# Filtering points...
#
# Merging points within bbox x = (144.90211022240885, 145.86890709668523), y = (14.110663153381893, 20.55540599159326) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country MNP complete in 1.27 seconds (33297.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country BHR
# --------------------------------------------------------------------------- (209/216)
#
# Filtering points...
#
# Merging points within bbox x = (50.448903842438426, 50.64565981295004), y = (25.789536850944955, 26.242580470612268) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country BHR complete in 1.28 seconds (33298.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country MAC
# --------------------------------------------------------------------------- (210/216)
#
# Filtering points...
#
# Merging points within bbox x = (113.51986738367293, 113.58749433669436), y = (22.105373440232142, 22.220770575401787) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country MAC complete in 1.24 seconds (33299.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country NLD
# --------------------------------------------------------------------------- (211/216)
#
# Filtering points...
#
# Merging points within bbox x = (-68.41738847619717, -68.19001217372278), y = (12.022040105766337, 12.310207423733686) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country NLD complete in 1.25 seconds (33301.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country NLD
# --------------------------------------------------------------------------- (212/216)
#
# Filtering points...
#
# Merging points within bbox x = (-62.99714108029656, -62.94506450981925), y = (17.464571174020534, 17.525620835433244) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country NLD complete in 1.25 seconds (33302.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country NLD
# --------------------------------------------------------------------------- (213/216)
#
# Filtering points...
#
# Merging points within bbox x = (-63.251332160650634, -63.223703579956236), y = (17.61469147333287, 17.646918035838723) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country NLD complete in 1.26 seconds (33303.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country NLD
# --------------------------------------------------------------------------- (214/216)
#
# Filtering points...
#
# Merging points within bbox x = (3.3494146741479653, 7.198505899727536), y = (50.74754954017919, 53.55809153869359) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country NLD complete in 4.16 seconds (33307.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country NZL
# --------------------------------------------------------------------------- (215/216)
#
# Filtering points...
#
# Merging points within bbox x = (-172.50255286372365, -171.1856583318665), y = (-9.361748956449162, -8.543226820661175) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country NZL complete in 1.43 seconds (33309.0 seconds overall)
#
# ---------------------------------------------------------------------------
#
#
#
# Starting country NZL
# --------------------------------------------------------------------------- (216/216)
#
# Filtering points...
#
# Merging points within bbox x = (-177.95799720011067, 178.84392337326517), y = (-52.6003132707408, -29.221937758021056) to country...
#
# Aggregating counts by climate...
#
# Appending output...
# Dropping indices...
#
# ---------------------------------------------------------------------------
#
# Country NZL complete in 27.3 seconds (33336.0 seconds overall)
#
# ---------------------------------------------------------------------------

# %% [markdown]
# # NOTE: CAN START HERE
# - Only need to unzip and load `os.path.join(dir_data, "kcc_cells_merged_to_country", "kcc_coords_index.csv")`
# - country-level values are stored in `os.path.join(dir_data, "kcc_cells_merged_to_country")` with name `f"kcc_by_country_{iso}.csv"`

# %%
pd.DataFrame(
    dfc
).to_csv(
    os.path.join(dir_data, "kcc_cells_merged_to_country", "kcc_coords_index.csv"),
    index = None,
    encoding = "UTF-8"
)

# %%
#df_out_full = pd.concat(df_out, axis = 0).reset_index(drop = True);
df_out_agg = pd.concat(df_agg_out, axis = 0).reset_index(drop = True);

# export output
#df_out_full.to_csv(sa.fp_csv_kcc_cells_merged_to_country, index = None, encoding = "UTF-8")
df_out_agg.to_csv(sa.fp_csv_kcc_cell_counts_by_country_kcc, index = None, encoding = "UTF-8")

# %%
dir_exp = os.path.join(dir_data, "kcc_cells_merged_to_country")
os.makedirs(dir_exp, exist_ok = True)

for df in df_out:
    iso = str(df[field_en].iloc[0])
    fp_write = os.path.join(dir_exp, f"kcc_by_country_{iso}.csv")
    df.drop(field_en, axis = 1).to_csv(fp_write, index = None, encoding = "UTF-8")
    print(f"country '{iso}' complete.\n")
# Out:
# country 'IDN' complete.
#
# country 'MYS' complete.
#
# country 'CHL' complete.
#
# country 'BOL' complete.
#
# country 'PER' complete.
#
# country 'ARG' complete.
#
# country 'CYP' complete.
#
# country 'IND' complete.
#
# country 'CHN' complete.
#
# country 'ISR' complete.
#
# country 'LBN' complete.
#
# country 'ETH' complete.
#
# country 'SSD' complete.
#
# country 'SOM' complete.
#
# country 'KEN' complete.
#
# country 'PAK' complete.
#
# country 'MWI' complete.
#
# country 'TZA' complete.
#
# country 'SYR' complete.
#
# country 'SUR' complete.
#
# country 'GUY' complete.
#
# country 'KOR' complete.
#
# country 'PRK' complete.
#
# country 'MAR' complete.
#
# country 'CRI' complete.
#
# country 'NIC' complete.
#
# country 'COG' complete.
#
# country 'COD' complete.
#
# country 'BTN' complete.
#
# country 'UKR' complete.
#
# country 'BLR' complete.
#
# country 'NAM' complete.
#
# country 'ZAF' complete.
#
# country 'MAF' complete.
#
# country 'SXM' complete.
#
# country 'OMN' complete.
#
# country 'UZB' complete.
#
# country 'KAZ' complete.
#
# country 'TJK' complete.
#
# country 'LTU' complete.
#
# country 'BRA' complete.
#
# country 'URY' complete.
#
# country 'MNG' complete.
#
# country 'RUS' complete.
#
# country 'CZE' complete.
#
# country 'DEU' complete.
#
# country 'EST' complete.
#
# country 'LVA' complete.
#
# country 'SWE' complete.
#
# country 'FIN' complete.
#
# country 'VNM' complete.
#
# country 'KHM' complete.
#
# country 'LUX' complete.
#
# country 'ARE' complete.
#
# country 'BEL' complete.
#
# country 'GEO' complete.
#
# country 'MKD' complete.
#
# country 'ALB' complete.
#
# country 'AZE' complete.
#
# country 'TUR' complete.
#
# country 'ESP' complete.
#
# country 'LAO' complete.
#
# country 'KGZ' complete.
#
# country 'ARM' complete.
#
# country 'DNK' complete.
#
# country 'LBY' complete.
#
# country 'TUN' complete.
#
# country 'ROU' complete.
#
# country 'HUN' complete.
#
# country 'SVK' complete.
#
# country 'POL' complete.
#
# country 'IRL' complete.
#
# country 'GBR' complete.
#
# country 'GRC' complete.
#
# country 'ZMB' complete.
#
# country 'SLE' complete.
#
# country 'GIN' complete.
#
# country 'LBR' complete.
#
# country 'CAF' complete.
#
# country 'SDN' complete.
#
# country 'DJI' complete.
#
# country 'ERI' complete.
#
# country 'AUT' complete.
#
# country 'IRQ' complete.
#
# country 'ITA' complete.
#
# country 'CHE' complete.
#
# country 'IRN' complete.
#
# country 'LIE' complete.
#
# country 'CIV' complete.
#
# country 'SRB' complete.
#
# country 'MLI' complete.
#
# country 'SEN' complete.
#
# country 'NGA' complete.
#
# country 'BEN' complete.
#
# country 'AGO' complete.
#
# country 'HRV' complete.
#
# country 'SVN' complete.
#
# country 'QAT' complete.
#
# country 'SAU' complete.
#
# country 'BWA' complete.
#
# country 'ZWE' complete.
#
# country 'BGR' complete.
#
# country 'THA' complete.
#
# country 'SMR' complete.
#
# country 'HTI' complete.
#
# country 'DOM' complete.
#
# country 'TCD' complete.
#
# country 'KWT' complete.
#
# country 'SLV' complete.
#
# country 'GTM' complete.
#
# country 'TLS' complete.
#
# country 'BRN' complete.
#
# country 'MCO' complete.
#
# country 'DZA' complete.
#
# country 'MOZ' complete.
#
# country 'SWZ' complete.
#
# country 'BDI' complete.
#
# country 'RWA' complete.
#
# country 'MMR' complete.
#
# country 'BGD' complete.
#
# country 'AND' complete.
#
# country 'AFG' complete.
#
# country 'MNE' complete.
#
# country 'BIH' complete.
#
# country 'UGA' complete.
#
# country 'CUB' complete.
#
# country 'HND' complete.
#
# country 'ECU' complete.
#
# country 'COL' complete.
#
# country 'PRY' complete.
#
# country 'PRT' complete.
#
# country 'MDA' complete.
#
# country 'TKM' complete.
#
# country 'JOR' complete.
#
# country 'NPL' complete.
#
# country 'LSO' complete.
#
# country 'CMR' complete.
#
# country 'GAB' complete.
#
# country 'NER' complete.
#
# country 'BFA' complete.
#
# country 'TGO' complete.
#
# country 'GHA' complete.
#
# country 'GNB' complete.
#
# country 'GIB' complete.
#
# country 'USA' complete.
#
# country 'CAN' complete.
#
# country 'MEX' complete.
#
# country 'BLZ' complete.
#
# country 'PAN' complete.
#
# country 'VEN' complete.
#
# country 'PNG' complete.
#
# country 'EGY' complete.
#
# country 'YEM' complete.
#
# country 'MRT' complete.
#
# country 'GNQ' complete.
#
# country 'GMB' complete.
#
# country 'HKG' complete.
#
# country 'AUS' complete.
#
# country 'GRL' complete.
#
# country 'FJI' complete.
#
# country 'NCL' complete.
#
# country 'MDG' complete.
#
# country 'PHL' complete.
#
# country 'LKA' complete.
#
# country 'CUW' complete.
#
# country 'ABW' complete.
#
# country 'BHS' complete.
#
# country 'TCA' complete.
#
# country 'JPN' complete.
#
# country 'ISL' complete.
#
# country 'PYF' complete.
#
# country 'SYC' complete.
#
# country 'KIR' complete.
#
# country 'MHL' complete.
#
# country 'TTO' complete.
#
# country 'GRD' complete.
#
# country 'VCT' complete.
#
# country 'BRB' complete.
#
# country 'LCA' complete.
#
# country 'DMA' complete.
#
# country 'ATG' complete.
#
# country 'KNA' complete.
#
# country 'VIR' complete.
#
# country 'PRI' complete.
#
# country 'VGB' complete.
#
# country 'JAM' complete.
#
# country 'CYM' complete.
#
# country 'BMU' complete.
#
# country 'MUS' complete.
#
# country 'COM' complete.
#
# country 'STP' complete.
#
# country 'CPV' complete.
#
# country 'MLT' complete.
#
# country 'IMN' complete.
#
# country 'FRO' complete.
#
# country 'SGP' complete.
#
# country 'TON' complete.
#
# country 'WSM' complete.
#
# country 'SLB' complete.
#
# country 'TUV' complete.
#
# country 'MDV' complete.
#
# country 'NRU' complete.
#
# country 'FSM' complete.
#
# country 'VUT' complete.
#
# country 'ASM' complete.
#
# country 'PLW' complete.
#
# country 'GUM' complete.
#
# country 'MNP' complete.
#
# country 'BHR' complete.
#
# country 'MAC' complete.
#
# country 'NLD' complete.
#
# country 'NLD' complete.
#
# country 'NLD' complete.
#
# country 'NLD' complete.
#
# country 'NZL' complete.
#
# country 'NZL' complete.

# %%
##
##  BUILD FRACTIONS WET/DRY AND TEMPERATE/TROPICAL BY COUNTRY
##

df_out_agg["count"] = df_out_agg["count"].astype(int)

# get total counts
df_out_agg_totals = (
    sf.simple_df_agg(
        df_out_agg[[field_en, "count"]],
        [field_en],
        {"count": "sum"}
    )
    .rename(columns = {"count": "total_count"})
)
# 
df_climate_by_country = pd.merge(
    df_out_agg, 
    df_climate_cats[["code_num", "wet_dry_cat", "temperate_tropical_cat"]].rename(columns = {"code_num": "kcc"})
)

# break out by wet/dry and temperate/tropical
df_climate_by_country_temptrop = df_climate_by_country.drop(["wet_dry_cat"], axis = 1)
df_climate_by_country_wetdry = df_climate_by_country.drop(["temperate_tropical_cat"], axis = 1)
all_countries = sorted(list(set(df_climate_by_country[field_en])))

# loop over different splits
fields_loop = ["wet_dry_cat", "temperate_tropical_cat"]
dict_df_climate_aggs = {}


if True:
    for field in fields_loop:

        fields_grp = [field_en, field]
        fields_dat = ["count"]

        all_vals = sorted(list(set(df_climate_by_country[field])))
        df_tmp = df_climate_by_country.drop([x for x in fields_loop if (x != field)], axis = 1)
        dict_agg = dict(zip(fields_grp, ["first" for x in fields_grp]))
        dict_agg.update(dict(zip(fields_dat, ["sum" for x in fields_dat])))

        df_tmp = df_tmp[fields_grp + fields_dat].groupby(fields_grp).agg(dict_agg).reset_index(drop = True)
        df_expand = pd.DataFrame(itertools.product(all_countries, all_vals), columns = [field_en, field])
        df_expand = pd.merge(df_expand, df_out_agg_totals, how = "left").fillna(0)

        df_tmp = pd.merge(df_expand, df_tmp, how = "left").fillna(0)
        df_tmp["frac"] = np.array(df_tmp["count"])/np.array(df_tmp["total_count"])
        df_tmp.rename(columns = {field_en: "country"}, inplace = True)


        # get pivot
        df_piv = pd.pivot(
            df_tmp[["country", field, "frac"]],
            index = ["country"],
            columns = [field], 
            values = ["frac"]
        ).reset_index()
        df_piv.columns = df_piv.columns.to_flat_index()
        dict_rnm = dict([(x, x[1].replace(")", "").strip()) for x in df_piv.columns if (x[1] != "")])
        dict_rnm.update({("country", ""): "country"})
        df_piv.rename(columns = dict_rnm, inplace = True)

        dict_df_climate_aggs.update({field: df_piv})

# %%
##  TEMPERATE/TROPICAL SPLITS

varlist_tt = []
# ag temp/trop vars
varlist_tt += sa.model_attributes.build_varlist(sa.model_attributes.subsec_name_agrc, model_afolu.modvar_agrc_frac_temperate)
varlist_tt += sa.model_attributes.build_varlist(sa.model_attributes.subsec_name_agrc, model_afolu.modvar_agrc_frac_tropical)
# frst temp/trop vars
varlist_tt += sa.model_attributes.build_varlist(sa.model_attributes.subsec_name_frst, model_afolu.modvar_frst_frac_temperate_nutrient_rich)
varlist_tt += sa.model_attributes.build_varlist(sa.model_attributes.subsec_name_frst, model_afolu.modvar_frst_frac_temperate_nutrient_poor)
varlist_tt += sa.model_attributes.build_varlist(sa.model_attributes.subsec_name_frst, model_afolu.modvar_frst_frac_tropical)
# lndu temp/trop vars
varlist_tt += sa.model_attributes.build_varlist(sa.model_attributes.subsec_name_lndu, model_afolu.modvar_lndu_frac_temperate)
varlist_tt += sa.model_attributes.build_varlist(sa.model_attributes.subsec_name_lndu, model_afolu.modvar_lndu_frac_tropical)


##  WET/DRY SPLITS

varlist_wd = []
# ag temp/trop vars
varlist_wd += sa.model_attributes.build_varlist(sa.model_attributes.subsec_name_agrc, model_afolu.modvar_agrc_frac_wet)
varlist_wd += sa.model_attributes.build_varlist(sa.model_attributes.subsec_name_agrc, model_afolu.modvar_agrc_frac_dry)
# lndu temp/trop vars
varlist_wd += sa.model_attributes.build_varlist(sa.model_attributes.subsec_name_lndu, model_afolu.modvar_lndu_frac_wet)
varlist_wd += sa.model_attributes.build_varlist(sa.model_attributes.subsec_name_lndu, model_afolu.modvar_lndu_frac_dry)

# %%
df_years = pd.DataFrame({time_periods.field_year: range(2010, time_periods.year_max + 1)})

df_ret = dict_df_climate_aggs[field][["country"]].copy()

for field in dict_df_climate_aggs.keys():
    
    loop = varlist_tt if (field == "temperate_tropical_cat") else varlist_wd
    for var in loop:
        if field == "temperate_tropical_cat":
            fld = "temperate" if ("temperate" in var) else ("tropical")
        else:
            fld = "wet" if ("wet" in var) else "dry"
        div = 2 if (("nutrient_poor" in var) or ("nutrient_rich" in var)) else 1
        df_merge = dict_df_climate_aggs[field][["country", fld]].copy().rename(columns = {fld: var})
        df_ret = pd.merge(df_ret, df_merge)
        df_ret[var] = np.array(df_ret[var])/div

# merge in time period
df_ret = sf.explode_merge(
    df_years,
    df_ret
)
df_ret = time_periods.years_to_tps(df_ret)
df_ret.rename(columns = {"country": regions.field_iso}, inplace = True)
fields_sort = [regions.field_iso, time_periods.field_time_period, time_periods.field_year]

df_ret = (
    df_ret[fields_sort + sorted([x for x in df_ret.columns if (x not in fields_sort)])]
    .sort_values(by = fields_sort)
    .reset_index(drop = True)
)

df_ret.to_csv(
    sa.fp_csv_climate_fields_by_country_simple, index = None, encoding = "UTF-8"
)

# %%
#[[fields_sort] + sorted([x for x in df_ret.columns if (x not in fields_sort)])]

# %%
for var_name in varlist_soc:
    df_agg_all_fields[var_name] = np.array(df_agg_all_fields[field_cp])

df_agg_all_fields.drop(field_cp, axis = 1, inplace = True)
df_agg_all_fields.rename(columns = {field_en: field_country}, inplace = True)
# Out:
#      country  time_period  frac_agrc_bevs_and_spices_cl1_temperate  \
# 0        ABW            0                                 1.000000
# 1        ABW            1                                 1.000000
# 2        ABW            2                                 1.000000
# 3        ABW            3                                 1.000000
# 4        ABW            4                                 1.000000
# ...      ...          ...                                      ...
# 7627     ZWE           31                                 0.989726
# 7628     ZWE           32                                 0.989726
# 7629     ZWE           33                                 0.989726
# 7630     ZWE           34                                 0.989726
# 7631     ZWE           35                                 0.989726
#
#       frac_agrc_bevs_and_spices_cl1_tropical  \
# 0                                   0.000000
# 1                                   0.000000
# 2                                   0.000000
# 3                                   0.000000
# 4                                   0.000000
# ...                                      ...
# 7627                                0.010274
# 7628                                0.010274
# 7629                                0.010274
# 7630                                0.010274
# 7631                                0.010274
#
#       frac_agrc_bevs_and_spices_cl2_dry  frac_agrc_bevs_and_spices_cl2_wet  \
# 0                              1.000000                           0.000000
# 1                              1.000000                           0.000000
# 2                              1.000000                           0.000000
# 3                              1.000000                           0.000000
# 4                              1.000000                           0.000000
# ...                                 ...                                ...
# 7627                           0.989726                           0.010274
# 7628                           0.989726                           0.010274
# 7629                           0.989726                           0.010274
# 7630                           0.989726                           0.010274
# 7631                           0.989726                           0.010274
#
#       frac_agrc_cereals_cl1_temperate  frac_agrc_cereals_cl1_tropical  \
# 0                            1.000000                        0.000000
# 1                            1.000000                        0.000000
# 2                            1.000000                        0.000000
# 3                            1.000000                        0.000000
# 4                            1.000000                        0.000000
# ...                               ...                             ...
# 7627                         0.989726                        0.010274
# 7628                         0.989726                        0.010274
# 7629                         0.989726                        0.010274
# 7630                         0.989726                        0.010274
# 7631                         0.989726                        0.010274
#
#       frac_agrc_cereals_cl2_dry  frac_agrc_cereals_cl2_wet  ...  \
# 0                      1.000000                   0.000000  ...
# 1                      1.000000                   0.000000  ...
# 2                      1.000000                   0.000000  ...
# 3                      1.000000                   0.000000  ...
# 4                      1.000000                   0.000000  ...
# ...                         ...                        ...  ...
# 7627                   0.989726                   0.010274  ...
# 7628                   0.989726                   0.010274  ...
# 7629                   0.989726                   0.010274  ...
# 7630                   0.989726                   0.010274  ...
# 7631                   0.989726                   0.010274  ...
#
#       frac_frst_secondary_cl1_temperate_nutrient_rich  \
# 0                                            0.500000
# 1                                            0.500000
# 2                                            0.500000
# 3                                            0.500000
# 4                                            0.500000
# ...                                               ...
# 7627                                         0.494863
# 7628                                         0.494863
# 7629                                         0.494863
# 7630                                         0.494863
# 7631                                         0.494863
#
#       frac_frst_secondary_cl1_tropical  frac_lndu_grasslands_cl1_temperate  \
# 0                             0.000000                            1.000000
# 1                             0.000000                            1.000000
# 2                             0.000000                            1.000000
# 3                             0.000000                            1.000000
# 4                             0.000000                            1.000000
# ...                                ...                                 ...
# 7627                          0.010274                            0.989726
# 7628                          0.010274                            0.989726
# 7629                          0.010274                            0.989726
# 7630                          0.010274                            0.989726
# 7631                          0.010274                            0.989726
#
#       frac_lndu_grasslands_cl1_tropical  frac_lndu_grasslands_cl2_dry  \
# 0                              0.000000                      1.000000
# 1                              0.000000                      1.000000
# 2                              0.000000                      1.000000
# 3                              0.000000                      1.000000
# 4                              0.000000                      1.000000
# ...                                 ...                           ...
# 7627                           0.010274                      0.989726
# 7628                           0.010274                      0.989726
# 7629                           0.010274                      0.989726
# 7630                           0.010274                      0.989726
# 7631                           0.010274                      0.989726
#
#       frac_lndu_grasslands_cl2_wet  frac_lndu_other_cl2_dry  \
# 0                         0.000000                 1.000000
# 1                         0.000000                 1.000000
# 2                         0.000000                 1.000000
# 3                         0.000000                 1.000000
# 4                         0.000000                 1.000000
# ...                            ...                      ...
# 7627                      0.010274                 0.989726
# 7628                      0.010274                 0.989726
# 7629                      0.010274                 0.989726
# 7630                      0.010274                 0.989726
# 7631                      0.010274                 0.989726
#
#       frac_lndu_other_cl2_wet  frac_lndu_settlements_cl2_dry  \
# 0                    0.000000                       1.000000
# 1                    0.000000                       1.000000
# 2                    0.000000                       1.000000
# 3                    0.000000                       1.000000
# 4                    0.000000                       1.000000
# ...                       ...                            ...
# 7627                 0.010274                       0.989726
# 7628                 0.010274                       0.989726
# 7629                 0.010274                       0.989726
# 7630                 0.010274                       0.989726
# 7631                 0.010274                       0.989726
#
#       frac_lndu_settlements_cl2_wet
# 0                          0.000000
# 1                          0.000000
# 2                          0.000000
# 3                          0.000000
# 4                          0.000000
# ...                             ...
# 7627                       0.010274
# 7628                       0.010274
# 7629                       0.010274
# 7630                       0.010274
# 7631                       0.010274
#
# [7632 rows x 71 columns]
