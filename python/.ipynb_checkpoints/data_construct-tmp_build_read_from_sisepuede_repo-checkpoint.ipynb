# %%
import batch_data_support_general as bds_gen
import importlib
import inspect
import itertools
import logging
import matplotlib.pyplot as plt
import model_attributes as ma
import model_afolu as mafl
import model_ippu as mi
import model_circular_economy as mc
import model_electricity as ml
import model_energy as me
import model_socioeconomic as se
import setup_analysis as sa
import support_classes as sc
import support_functions as sf
import numpy as np
import os, os.path
import pandas as pd
import pycountry
import re
import time
from typing import *
import warnings

warnings.filterwarnings("ignore")
# Out:
# /Users/jsyme/Documents/Projects/git_jbus/lac_decarbonization/python/model_attributes.py:2287: UserWarning: Invalid subsector attribute 'key_varreqs_partial'. Valid return type values are:'pycategory_primary', 'abv_subsector', 'sector', 'abv_sector', 'key_varreqs_all'
#   warnings.warn(f"Invalid subsector attribute '{return_type}'. Valid return type values are:{valid_rts}")

# %%
regions = sc.Regions(sa.model_attributes)
time_periods = sc.TimePeriods(sa.model_attributes)

# %%
def read_inputs_from_repository(
    dir_repo_data: str,
    dict_modvars: Dict[str, Union[List[str], None]],
    model_attributes: ma.ModelAttributes,
    field_iso: str = "iso_code3",
    field_year: str = "year",
    fields_drop: Union[List[str], None] = ["nation"],
    fields_index: Union[List[str], None] = None,
    fields_to_iso: Union[List[str], None] = ["location_code"],
    regions: Union[sc.Regions, None] = None,
    time_periods: Union[sc.TimePeriods, None] = None,
) -> pd.DataFrame: 
    """
    Read inputs from the repository for use.
    
    Function Arguements
    -------------------
    - dir_repo_data: directory containing data
    - dict_modvars: dictionary with model variables as keys and a list of 
        categories to apply to (or None to read all applicable)
    - model_attributes: model attributes object to use
        
    Keyword Arguements
    ------------------
    - field_iso: field storing the 3-digit alpha ISO code
    - field_year: field containing year
    - fields_drop: fields to drop from input files (always lower case)
    - fields_index: ORDERED fields to use for sorting (always lower case)
    - fields_to_iso: fields to convert to iso if present
    - regions: optional support_classes.Regions object to pass to prevent 
        endogenous instantiation
    - time_periods: optional support_classes.TimePeriods object to pass to 
        prevent endogenous instantiation
    """
    
    regions = (
        sc.Regions(model_attributes) 
        if not isinstance(regions, sc.Regions) 
        else regions
    )
    time_periods = (
        sc.TimePeriods(model_attributes) 
        if not isinstance(time_periods, sc.TimePeriods) 
        else time_periods
    )

    # some needed dictionaries
    dict_subsec_to_subdir = {
        "AFOLU": "AFOLU",
        "Energy": "Energy",
        "IPPU": "IPPU", 
        "Socioeconomic": "SocioEconomic"
    }
    dict_subsec_abv_to_sector = model_attributes.dict_attributes.get("abbreviation_subsector").field_maps.get("abbreviation_subsector_to_sector")
    dict_subsec_to_subsec_abv = model_attributes.dict_attributes.get("abbreviation_subsector").field_maps.get("subsector_to_abbreviation_subsector")
    dict_modvars = (
        dict((x, None) for x in model_attributes.all_model_variables)
        if not isinstance(dict_modvars, dict)
        else dict_modvars
    ) 
    
    
    # some fields
    field_iso = field_iso.lower() if isinstance(field_iso, str) else "iso_code3"
    field_year = field_year.lower() if isinstance(field_year, str) else "year"
    fields_index = [field_iso, field_year] if (fields_index is None) else [x.lower() for x in fields_index if isinstance(x, str)]
    fields_to_iso = [] if not isinstance(fields_to_iso, list) else fields_to_iso
    
    # initialize output
    df_out = None
    df_index = None # used to govern merges
    dict_modvar_to_fields = {}
    dict_modvar_to_ordered_cats = {}
    
    modvars = list(dict_modvars.keys())
    
    for k, modvar in enumerate(modvars):
        
        cats_defined = model_attributes.get_variable_categories(modvar)
        cats = dict_modvars.get(modvar)
        cats = cats_defined if (cats is None) else cats
        cats = (
            [x for x in cats_defined if x in cats]
            if (cats_defined is not None)
            else [None]
        )
        
        subsec = model_attributes.get_variable_subsector(modvar)
        sector = dict_subsec_abv_to_sector.get(
            dict_subsec_to_subsec_abv.get(subsec)
        )
        sector_repo = dict_subsec_to_subdir.get(sector)
        
        
        if (sector_repo is not None) and (len(cats) > 0):

            for cat in cats:
                
                restriction = None if (cat is None) else [cat]
                
                var_name = model_attributes.build_varlist(
                    subsec,
                    modvar, 
                    restrict_to_category_values = restriction
                )[0]

                df_var = []
                
                for subdir in ["historical", "projected"]:
                    
                    fp_read = os.path.join(
                        dir_repo_data, 
                        sector_repo, 
                        var_name,
                        "input_to_sisepuede",
                        subdir, 
                        f"{var_name}.csv"
                    )

                    if os.path.exists(fp_read):
                        
                        try:
                            # read
                            df_var_cur = pd.read_csv(fp_read)
                            
                            # rename where necessary
                            dict_rnm_to_iso = dict(
                                (x, field_iso) 
                                for x in fields_to_iso
                                if x in df_var_cur.columns
                            )
                            df_var_cur.rename(
                                columns = dict_rnm_to_iso,
                                inplace = True
                            )
                            
                            # clean the fields
                            dict_rnm = dict((x, x.lower()) for x in df_var_cur.columns)
                            df_var_cur.rename(
                                columns = dict_rnm,
                                inplace = True
                            )

                            # drop any unwanted columns
                            df_var_cur = df_var_cur[fields_index + [var_name]]
                            df_var_cur.set_index(fields_index, inplace = True)

                            if subdir == "projected":
                                inds_prev = df_var[0].index
                                df_var_cur = df_var_cur[
                                    [(x not in inds_prev) for x in df_var_cur.index]
                                ]
                                df_var[0].reset_index(inplace = True)
                                df_var_cur.reset_index(inplace = True)
                            
                            df_var.append(df_var_cur)

                        except Exception as e:
                            warnings.warn(f"Error trying to read {fp_read}: {e}")
                            
                    

                # concatenate and sort
                df_var = pd.concat(df_var, axis = 0) if (len(df_var) > 0) else None
                
                if ((fields_index is not None) and (df_var is not None)):                    
                    # get dictionaries
                    fields_add = sorted([x for x in df_var.columns if x not in fields_index])
                    fields_exist = dict_modvar_to_fields.get(modvar)
                    
                    (
                        dict_modvar_to_fields.update({modvar: fields_add}) 
                        if fields_exist is None
                        else dict_modvar_to_fields[modvar].extend(fields_add)
                    )
                    
                    (
                        dict_modvar_to_ordered_cats.update({modvar: [cat]}) 
                        if fields_exist is None
                        else dict_modvar_to_ordered_cats[modvar].append(cat)
                    )
                    
                    
                if df_var is not None:

                    df_var.sort_values(by = fields_index, inplace = True)
                    #df_var.set_index(fields_index, inplace = True)
                    
                    df_var.reset_index(drop = True, inplace = True)

                    if (df_out is None):

                        df_out = [df_var]
                        df_index = df_var[fields_index].copy()

                    else:
                        #df_out.append(df_var)
                        
                        
                        fold_q = (
                            True
                            if df_var[fields_index].shape != df_index.shape
                            else not all(df_var[fields_index] == df_index)
                        )

                        # setup indexing data frame
                        if fold_q:
                            df_out = pd.concat(df_out, axis = 1)

                            df_index = (
                                pd.merge(
                                    df_index, 
                                    df_var[fields_index],
                                    how = "outer"
                                )
                                .sort_values(by = fields_index)
                                .reset_index(drop = True)
                            )


                            df_out = (
                                pd.merge(
                                    df_index, 
                                    df_out, 
                                    how = "left", 
                                    on = fields_index
                                )
                                .sort_index()
                                .reset_index(drop = True)
                            )
                            df_out = [df_out]
                            df_var = (
                                pd.merge(
                                    df_index, 
                                    df_var, 
                                    how = "left", 
                                    on = fields_index
                                )
                                .sort_index()
                                .reset_index(drop = True)
                            )

                        #""";
                        print(f"appended {var_name}")
                        print(df_index.shape)
                        print(df_out[0].shape)
                        print(df_var.shape)
                        print("\n")
                        df_out.append(df_var[[var_name]])

    print("here") 
    if (df_out is not None) and (fields_index is not None):

        """
        df_out = (
            df_out[0].join(
                df_out[1:],
                how = "outer"
            )
            if len(df_out) > 1
            else df_out[0]
        )
        """;
        df_out = pd.concat(df_out, axis = 1)
        df_out.sort_values(by = fields_index, inplace = True) 
        df_out.reset_index(drop = False, inplace = True) 
            
    return df_out, dict_modvar_to_fields, dict_modvar_to_ordered_cats

# %%
dir_repo_data = "/Users/jsyme/Documents/Projects/git_jbus/sisepuede_data"
t0 = time.time()
df_complete, dict_modvar_to_fields, dict_modvar_to_ordered_cats = read_inputs_from_repository(dir_repo_data, None, sa.model_attributes)
sf.get_time_elapsed(t0)
# Out:
# appended frac_agrc_cereals_cl2_dry
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_fibers_cl2_dry
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_fruits_cl2_dry
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_herbs_and_other_perennial_crops_cl2_dry
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_nuts_cl2_dry
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_other_annual_cl2_dry
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_other_woody_perennial_cl2_dry
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_pulses_cl2_dry
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_rice_cl2_dry
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_sugar_cane_cl2_dry
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_tubers_cl2_dry
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_vegetables_and_vines_cl2_dry
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_bevs_and_spices_cl1_temperate
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_cereals_cl1_temperate
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_fibers_cl1_temperate
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_fruits_cl1_temperate
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_herbs_and_other_perennial_crops_cl1_temperate
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_nuts_cl1_temperate
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_other_annual_cl1_temperate
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_other_woody_perennial_cl1_temperate
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_pulses_cl1_temperate
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_rice_cl1_temperate
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_sugar_cane_cl1_temperate
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_tubers_cl1_temperate
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_vegetables_and_vines_cl1_temperate
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_bevs_and_spices_cl1_tropical
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_cereals_cl1_tropical
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_fibers_cl1_tropical
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_fruits_cl1_tropical
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_herbs_and_other_perennial_crops_cl1_tropical
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_nuts_cl1_tropical
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_other_annual_cl1_tropical
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_other_woody_perennial_cl1_tropical
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_pulses_cl1_tropical
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_rice_cl1_tropical
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_sugar_cane_cl1_tropical
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_tubers_cl1_tropical
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_vegetables_and_vines_cl1_tropical
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_bevs_and_spices_cl2_wet
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_cereals_cl2_wet
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_fibers_cl2_wet
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_fruits_cl2_wet
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_herbs_and_other_perennial_crops_cl2_wet
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_nuts_cl2_wet
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_other_annual_cl2_wet
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_other_woody_perennial_cl2_wet
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_pulses_cl2_wet
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_rice_cl2_wet
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_sugar_cane_cl2_wet
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_tubers_cl2_wet
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended frac_agrc_vegetables_and_vines_cl2_wet
# (8815, 2)
# (8815, 3)
# (8815, 3)
#
#
# appended yf_agrc_bevs_and_spices_tonne_ha
# (9136, 2)
# (9136, 54)
# (9136, 3)
#
#
# appended yf_agrc_cereals_tonne_ha
# (9136, 2)
# (9136, 55)
# (9136, 3)
#
#
# appended yf_agrc_fibers_tonne_ha
# (9136, 2)
# (9136, 56)
# (9136, 3)
#
#
# appended yf_agrc_fruits_tonne_ha
# (9136, 2)
# (9136, 57)
# (9136, 3)
#
#
# appended yf_agrc_herbs_and_other_perennial_crops_tonne_ha
# (9136, 2)
# (9136, 58)
# (9136, 3)
#
#
# appended yf_agrc_nuts_tonne_ha
# (9136, 2)
# (9136, 59)
# (9136, 3)
#
#
# appended yf_agrc_other_annual_tonne_ha
# (9136, 2)
# (9136, 60)
# (9136, 3)
#
#
# appended yf_agrc_other_woody_perennial_tonne_ha
# (9136, 2)
# (9136, 61)
# (9136, 3)
#
#
# appended yf_agrc_pulses_tonne_ha
# (9136, 2)
# (9136, 62)
# (9136, 3)
#
#
# appended yf_agrc_rice_tonne_ha
# (9136, 2)
# (9136, 63)
# (9136, 3)
#
#
# appended yf_agrc_sugar_cane_tonne_ha
# (9136, 2)
# (9136, 64)
# (9136, 3)
#
#
# appended yf_agrc_tubers_tonne_ha
# (9136, 2)
# (9136, 65)
# (9136, 3)
#
#
# appended yf_agrc_vegetables_and_vines_tonne_ha
# (9136, 2)
# (9136, 66)
# (9136, 3)
#
#
# appended gdp_mmm_usd
# (9137, 2)
# (9137, 67)
# (9137, 3)
#
#
# appended efficfactor_enfu_industrial_energy_fuel_biomass
# (10298, 2)
# (10298, 68)
# (10298, 3)
#
#
# appended efficfactor_enfu_industrial_energy_fuel_coal
# (10298, 2)
# (10298, 69)
# (10298, 3)
#
#
# appended efficfactor_enfu_industrial_energy_fuel_coke
# (10298, 2)
# (10298, 70)
# (10298, 3)
#
#
# appended efficfactor_enfu_industrial_energy_fuel_diesel
# (10298, 2)
# (10298, 71)
# (10298, 3)
#
#
# appended efficfactor_enfu_industrial_energy_fuel_electricity
# (10298, 2)
# (10298, 72)
# (10298, 3)
#
#
# appended efficfactor_enfu_industrial_energy_fuel_gasoline
# (10298, 2)
# (10298, 73)
# (10298, 3)
#
#
# appended efficfactor_enfu_industrial_energy_fuel_hydrogen
# (10298, 2)
# (10298, 74)
# (10298, 3)
#
#
# appended efficfactor_enfu_industrial_energy_fuel_kerosene
# (10298, 2)
# (10298, 75)
# (10298, 3)
#
#
# appended efficfactor_enfu_industrial_energy_fuel_natural_gas
# (10298, 2)
# (10298, 76)
# (10298, 3)
#
#
# appended efficfactor_enfu_industrial_energy_fuel_oil
# (10298, 2)
# (10298, 77)
# (10298, 3)
#
#
# appended efficfactor_enfu_industrial_energy_fuel_solar
# (10298, 2)
# (10298, 78)
# (10298, 3)
#
#
# appended frac_enfu_transmission_loss_fuel_electricity
# (10298, 2)
# (10298, 79)
# (10298, 3)
#
#
# appended frac_enfu_fuel_demand_imported_pj_fuel_coal
# (13406, 2)
# (13406, 80)
# (13406, 3)
#
#
# appended frac_enfu_fuel_demand_imported_pj_fuel_crude
# (13910, 2)
# (13910, 81)
# (13910, 3)
#
#
# appended frac_enfu_fuel_demand_imported_pj_fuel_diesel
# (13990, 2)
# (13990, 82)
# (13990, 3)
#
#
# appended frac_enfu_fuel_demand_imported_pj_fuel_electricity
# (13990, 2)
# (13990, 83)
# (13990, 3)
#
#
# appended frac_enfu_fuel_demand_imported_pj_fuel_gasoline
# (13990, 2)
# (13990, 84)
# (13990, 3)
#
#
# appended frac_enfu_fuel_demand_imported_pj_fuel_hydrocarbon_gas_liquids
# (13990, 2)
# (13990, 85)
# (13990, 3)
#
#
# appended frac_enfu_fuel_demand_imported_pj_fuel_kerosene
# (13990, 2)
# (13990, 86)
# (13990, 3)
#
#
# appended frac_enfu_fuel_demand_imported_pj_fuel_natural_gas
# (13990, 2)
# (13990, 87)
# (13990, 3)
#
#
# appended frac_enfu_fuel_demand_imported_pj_fuel_oil
# (13990, 2)
# (13990, 88)
# (13990, 3)
#
#
# appended exports_enfu_pj_fuel_coal
# (15477, 2)
# (15477, 89)
# (15477, 3)
#
#
# appended exports_enfu_pj_fuel_crude
# (15477, 2)
# (15477, 90)
# (15477, 3)
#
#
# appended exports_enfu_pj_fuel_diesel
# (15477, 2)
# (15477, 91)
# (15477, 3)
#
#
# appended exports_enfu_pj_fuel_electricity
# (15477, 2)
# (15477, 92)
# (15477, 3)
#
#
# appended exports_enfu_pj_fuel_gasoline
# (15477, 2)
# (15477, 93)
# (15477, 3)
#
#
# appended exports_enfu_pj_fuel_hydrocarbon_gas_liquids
# (15477, 2)
# (15477, 94)
# (15477, 3)
#
#
# appended exports_enfu_pj_fuel_kerosene
# (15477, 2)
# (15477, 95)
# (15477, 3)
#
#
# appended exports_enfu_pj_fuel_natural_gas
# (15477, 2)
# (15477, 96)
# (15477, 3)
#
#
# appended exports_enfu_pj_fuel_oil
# (15477, 2)
# (15477, 97)
# (15477, 3)
#
#
# appended cost_enfu_fuel_biomass_usd_per_tonne
# (15477, 2)
# (15477, 98)
# (15477, 3)
#
#
# appended cost_enfu_fuel_coal_usd_per_tonne
# (15477, 2)
# (15477, 99)
# (15477, 3)
#
#
# appended cost_enfu_fuel_coke_usd_per_tonne
# (15477, 2)
# (15477, 100)
# (15477, 3)
#
#
# appended cost_enfu_fuel_nuclear_usd_per_tonne
# (18858, 2)
# (18858, 101)
# (18858, 3)
#
#
# appended cost_enfu_fuel_biogas_usd_per_mmbtu
# (18858, 2)
# (18858, 102)
# (18858, 3)
#
#
# appended cost_enfu_fuel_electricity_usd_per_mmbtu
# (18858, 2)
# (18858, 103)
# (18858, 3)
#
#
# appended cost_enfu_fuel_hydrocarbon_gas_liquids_usd_per_mmbtu
# (18858, 2)
# (18858, 104)
# (18858, 3)
#
#
# appended cost_enfu_fuel_hydrogen_usd_per_mmbtu
# (18858, 2)
# (18858, 105)
# (18858, 3)
#
#
# appended cost_enfu_fuel_natural_gas_usd_per_mmbtu
# (18858, 2)
# (18858, 106)
# (18858, 3)
#
#
# appended cost_enfu_fuel_waste_usd_per_mmbtu
# (18858, 2)
# (18858, 107)
# (18858, 3)
#
#
# appended cost_enfu_fuel_biofuels_usd_per_m3
# (18858, 2)
# (18858, 108)
# (18858, 3)
#
#
# appended cost_enfu_fuel_crude_usd_per_m3
# (18858, 2)
# (18858, 109)
# (18858, 3)
#
#
# appended cost_enfu_fuel_diesel_usd_per_m3
# (18858, 2)
# (18858, 110)
# (18858, 3)
#
#
# appended cost_enfu_fuel_furnace_gas_usd_per_m3
# (18858, 2)
# (18858, 111)
# (18858, 3)
#
#
# appended cost_enfu_fuel_gasoline_usd_per_m3
# (18858, 2)
# (18858, 112)
# (18858, 3)
#
#
# appended cost_enfu_fuel_kerosene_usd_per_m3
# (18858, 2)
# (18858, 113)
# (18858, 3)
#
#
# appended cost_enfu_fuel_oil_usd_per_m3
# (18858, 2)
# (18858, 114)
# (18858, 3)
#
#
# appended nemomod_enst_capital_cost_st_batteries_usd_per_kwh
# (18858, 2)
# (18858, 115)
# (18858, 3)
#
#
# appended nemomod_enst_capital_cost_st_compressed_air_usd_per_kwh
# (18858, 2)
# (18858, 116)
# (18858, 3)
#
#
# appended nemomod_enst_capital_cost_st_flywheels_usd_per_kwh
# (18858, 2)
# (18858, 117)
# (18858, 3)
#
#
# appended nemomod_entc_capital_cost_pp_biogas_mm_usd_per_gw
# (20472, 2)
# (20472, 118)
# (20472, 3)
#
#
# appended nemomod_entc_capital_cost_pp_biomass_mm_usd_per_gw
# (20523, 2)
# (20523, 119)
# (20523, 3)
#
#
# appended nemomod_entc_capital_cost_pp_coal_mm_usd_per_gw
# (20523, 2)
# (20523, 120)
# (20523, 3)
#
#
# appended nemomod_entc_capital_cost_pp_gas_mm_usd_per_gw
# (20523, 2)
# (20523, 121)
# (20523, 3)
#
#
# appended nemomod_entc_capital_cost_pp_geothermal_mm_usd_per_gw
# (20523, 2)
# (20523, 122)
# (20523, 3)
#
#
# appended nemomod_entc_capital_cost_pp_hydropower_mm_usd_per_gw
# (20523, 2)
# (20523, 123)
# (20523, 3)
#
#
# appended nemomod_entc_capital_cost_pp_nuclear_mm_usd_per_gw
# (20523, 2)
# (20523, 124)
# (20523, 3)
#
#
# appended nemomod_entc_capital_cost_pp_ocean_mm_usd_per_gw
# (20523, 2)
# (20523, 125)
# (20523, 3)
#
#
# appended nemomod_entc_capital_cost_pp_oil_mm_usd_per_gw
# (20523, 2)
# (20523, 126)
# (20523, 3)
#
#
# appended nemomod_entc_capital_cost_pp_solar_mm_usd_per_gw
# (20523, 2)
# (20523, 127)
# (20523, 3)
#
#
# appended nemomod_entc_capital_cost_pp_waste_incineration_mm_usd_per_gw
# (20523, 2)
# (20523, 128)
# (20523, 3)
#
#
# appended nemomod_entc_capital_cost_pp_wind_mm_usd_per_gw
# (20523, 2)
# (20523, 129)
# (20523, 3)
#
#
# appended nemomod_entc_fixed_cost_pp_biogas_mm_usd_per_gw
# (20523, 2)
# (20523, 130)
# (20523, 3)
#
#
# appended nemomod_entc_fixed_cost_pp_biomass_mm_usd_per_gw
# (20523, 2)
# (20523, 131)
# (20523, 3)
#
#
# appended nemomod_entc_fixed_cost_pp_coal_mm_usd_per_gw
# (20523, 2)
# (20523, 132)
# (20523, 3)
#
#
# appended nemomod_entc_fixed_cost_pp_gas_mm_usd_per_gw
# (20523, 2)
# (20523, 133)
# (20523, 3)
#
#
# appended nemomod_entc_fixed_cost_pp_geothermal_mm_usd_per_gw
# (20523, 2)
# (20523, 134)
# (20523, 3)
#
#
# appended nemomod_entc_fixed_cost_pp_hydropower_mm_usd_per_gw
# (20523, 2)
# (20523, 135)
# (20523, 3)
#
#
# appended nemomod_entc_fixed_cost_pp_nuclear_mm_usd_per_gw
# (20523, 2)
# (20523, 136)
# (20523, 3)
#
#
# appended nemomod_entc_fixed_cost_pp_ocean_mm_usd_per_gw
# (20523, 2)
# (20523, 137)
# (20523, 3)
#
#
# appended nemomod_entc_fixed_cost_pp_oil_mm_usd_per_gw
# (20523, 2)
# (20523, 138)
# (20523, 3)
#
#
# appended nemomod_entc_fixed_cost_pp_solar_mm_usd_per_gw
# (20523, 2)
# (20523, 139)
# (20523, 3)
#
#
# appended nemomod_entc_fixed_cost_pp_waste_incineration_mm_usd_per_gw
# (20523, 2)
# (20523, 140)
# (20523, 3)
#
#
# appended nemomod_entc_fixed_cost_pp_wind_mm_usd_per_gw
# (20523, 2)
# (20523, 141)
# (20523, 3)
#
#
# appended nemomod_entc_frac_min_share_production_pp_biomass
# (20523, 2)
# (20523, 142)
# (20523, 3)
#
#
# appended nemomod_entc_frac_min_share_production_pp_coal
# (20523, 2)
# (20523, 143)
# (20523, 3)
#
#
# appended nemomod_entc_frac_min_share_production_pp_gas
# (20523, 2)
# (20523, 144)
# (20523, 3)
#
#
# appended nemomod_entc_frac_min_share_production_pp_geothermal
# (20523, 2)
# (20523, 145)
# (20523, 3)
#
#
# appended nemomod_entc_frac_min_share_production_pp_hydropower
# (20523, 2)
# (20523, 146)
# (20523, 3)
#
#
# appended nemomod_entc_frac_min_share_production_pp_nuclear
# (20523, 2)
# (20523, 147)
# (20523, 3)
#
#
# appended nemomod_entc_frac_min_share_production_pp_ocean
# (20523, 2)
# (20523, 148)
# (20523, 3)
#
#
# appended nemomod_entc_frac_min_share_production_pp_oil
# (20523, 2)
# (20523, 149)
# (20523, 3)
#
#
# appended nemomod_entc_frac_min_share_production_pp_solar
# (20523, 2)
# (20523, 150)
# (20523, 3)
#
#
# appended nemomod_entc_residual_capacity_pp_biogas_gw
# (24822, 2)
# (24822, 151)
# (24822, 3)
#
#
# appended nemomod_entc_residual_capacity_pp_biomass_gw
# (25952, 2)
# (25952, 152)
# (25952, 3)
#
#
# appended nemomod_entc_residual_capacity_pp_coal_gw
# (25952, 2)
# (25952, 153)
# (25952, 3)
#
#
# appended nemomod_entc_residual_capacity_pp_gas_gw
# (25952, 2)
# (25952, 154)
# (25952, 3)
#
#
# appended nemomod_entc_residual_capacity_pp_geothermal_gw
# (25952, 2)
# (25952, 155)
# (25952, 3)
#
#
# appended nemomod_entc_residual_capacity_pp_hydropower_gw
# (25952, 2)
# (25952, 156)
# (25952, 3)
#
#
# appended nemomod_entc_residual_capacity_pp_nuclear_gw
# (25952, 2)
# (25952, 157)
# (25952, 3)
#
#
# appended nemomod_entc_residual_capacity_pp_ocean_gw
# (25952, 2)
# (25952, 158)
# (25952, 3)
#
#
# appended nemomod_entc_residual_capacity_pp_oil_gw
# (25952, 2)
# (25952, 159)
# (25952, 3)
#
#
# appended nemomod_entc_residual_capacity_pp_solar_gw
# (25952, 2)
# (25952, 160)
# (25952, 3)
#
#
# appended nemomod_entc_residual_capacity_pp_waste_incineration_gw
# (25952, 2)
# (25952, 161)
# (25952, 3)
#
#
# appended nemomod_entc_residual_capacity_pp_wind_gw
# (25952, 2)
# (25952, 162)
# (25952, 3)
#
#
# appended nemomod_entc_total_annual_max_capacity_pp_hydropower_gw
# (25952, 2)
# (25952, 163)
# (25952, 3)
#
#
# appended nemomod_entc_variable_cost_st_compressed_air_usd_per_mwh
# (25952, 2)
# (25952, 164)
# (25952, 3)
#
#
# appended frac_frst_mangroves_cl1_temperate_nutrient_poor
# (25952, 2)
# (25952, 165)
# (25952, 3)
#
#
# appended frac_frst_primary_cl1_temperate_nutrient_poor
# (25952, 2)
# (25952, 166)
# (25952, 3)
#
#
# appended frac_frst_secondary_cl1_temperate_nutrient_poor
# (25952, 2)
# (25952, 167)
# (25952, 3)
#
#
# appended frac_frst_mangroves_cl1_temperate_nutrient_rich
# (25952, 2)
# (25952, 168)
# (25952, 3)
#
#
# appended frac_frst_primary_cl1_temperate_nutrient_rich
# (25952, 2)
# (25952, 169)
# (25952, 3)
#
#
# appended frac_frst_secondary_cl1_temperate_nutrient_rich
# (25952, 2)
# (25952, 170)
# (25952, 3)
#
#
# appended frac_frst_mangroves_cl1_tropical
# (25952, 2)
# (25952, 171)
# (25952, 3)
#
#
# appended frac_frst_primary_cl1_tropical
# (25952, 2)
# (25952, 172)
# (25952, 3)
#
#
# appended frac_frst_secondary_cl1_tropical
# (25952, 2)
# (25952, 173)
# (25952, 3)
#
#
# appended area_gnrl_country_ha
# (25952, 2)
# (25952, 174)
# (25952, 3)
#
#
# appended occrateinit_gnrl_occupancy
# (25952, 2)
# (25952, 175)
# (25952, 3)
#
#
# appended population_gnrl_rural
# (25952, 2)
# (25952, 176)
# (25952, 3)
#
#
# appended population_gnrl_urban
# (25952, 2)
# (25952, 177)
# (25952, 3)
#
#
# appended ef_ippu_tonne_nf3_per_tonne_production_chemicals
# (25952, 2)
# (25952, 178)
# (25952, 3)
#
#
# appended ef_ippu_tonne_nf3_per_tonne_production_electronics
# (25952, 2)
# (25952, 179)
# (25952, 3)
#
#
# appended ef_ippu_tonne_sf6_per_mmm_gdp_other_product_manufacturing
# (25952, 2)
# (25952, 180)
# (25952, 3)
#
#
# appended ef_ippu_tonne_sf6_per_tonne_production_chemicals
# (25952, 2)
# (25952, 181)
# (25952, 3)
#
#
# appended ef_ippu_tonne_sf6_per_tonne_production_electronics
# (25952, 2)
# (25952, 182)
# (25952, 3)
#
#
# appended ef_ippu_tonne_sf6_per_tonne_production_metals
# (25952, 2)
# (25952, 183)
# (25952, 3)
#
#
# appended frac_ippu_cement_clinker
# (25952, 2)
# (25952, 184)
# (25952, 3)
#
#
# appended ef_ippu_tonne_c5f12_per_tonne_production_chemicals
# (25952, 2)
# (25952, 185)
# (25952, 3)
#
#
# appended ef_ippu_tonne_c2hf5_per_mmm_gdp_product_use_ods_other
# (25952, 2)
# (25952, 186)
# (25952, 3)
#
#
# appended ef_ippu_tonne_c2hf5_per_mmm_gdp_product_use_ods_refrigeration
# (25952, 2)
# (25952, 187)
# (25952, 3)
#
#
# appended ef_ippu_tonne_c2hf5_per_tonne_production_chemicals
# (25952, 2)
# (25952, 188)
# (25952, 3)
#
#
# appended ef_ippu_tonne_chf2cf3_per_mmm_gdp_product_use_ods_other
# (25952, 2)
# (25952, 189)
# (25952, 3)
#
#
# appended ef_ippu_tonne_chf2cf3_per_mmm_gdp_product_use_ods_refrigeration
# (25952, 2)
# (25952, 190)
# (25952, 3)
#
#
# appended ef_ippu_tonne_chf2cf3_per_tonne_production_chemicals
# (25952, 2)
# (25952, 191)
# (25952, 3)
#
#
# appended ef_ippu_tonne_c2h3f3_per_mmm_gdp_product_use_ods_refrigeration
# (25952, 2)
# (25952, 192)
# (25952, 3)
#
#
# appended ef_ippu_tonne_c2h3f3_per_tonne_production_chemicals
# (25952, 2)
# (25952, 193)
# (25952, 3)
#
#
# appended ef_ippu_tonne_ch3chf2_per_mmm_gdp_product_use_ods_other
# (25952, 2)
# (25952, 194)
# (25952, 3)
#
#
# appended ef_ippu_tonne_ch3chf2_per_mmm_gdp_product_use_ods_refrigeration
# (25952, 2)
# (25952, 195)
# (25952, 3)
#
#
# appended ef_ippu_tonne_ch3chf2_per_tonne_production_chemicals
# (25952, 2)
# (25952, 196)
# (25952, 3)
#
#
# appended ef_ippu_tonne_c3hf7_per_mmm_gdp_product_use_ods_other
# (25952, 2)
# (25952, 197)
# (25952, 3)
#
#
# appended ef_ippu_tonne_c3hf7_per_mmm_gdp_product_use_ods_refrigeration
# (25952, 2)
# (25952, 198)
# (25952, 3)
#
#
# appended ef_ippu_tonne_c3hf7_per_tonne_production_chemicals
# (25952, 2)
# (25952, 199)
# (25952, 3)
#
#
# appended ef_ippu_tonne_chf3_per_mmm_gdp_product_use_ods_other
# (25952, 2)
# (25952, 200)
# (25952, 3)
#
#
# appended ef_ippu_tonne_chf3_per_mmm_gdp_product_use_ods_refrigeration
# (25952, 2)
# (25952, 201)
# (25952, 3)
#
#
# appended ef_ippu_tonne_chf3_per_tonne_production_chemicals
# (25952, 2)
# (25952, 202)
# (25952, 3)
#
#
# appended ef_ippu_tonne_chf3_per_tonne_production_electronics
# (25952, 2)
# (25952, 203)
# (25952, 3)
#
#
# appended ef_ippu_tonne_c3h2f6_per_mmm_gdp_product_use_ods_other
# (25952, 2)
# (25952, 204)
# (25952, 3)
#
#
# appended ef_ippu_tonne_c3h2f6_per_mmm_gdp_product_use_ods_refrigeration
# (25952, 2)
# (25952, 205)
# (25952, 3)
#
#
# appended ef_ippu_tonne_c3h3f5_per_mmm_gdp_product_use_ods_other
# (25952, 2)
# (25952, 206)
# (25952, 3)
#
#
# appended ef_ippu_tonne_c3h3f5_per_mmm_gdp_product_use_ods_refrigeration
# (25952, 2)
# (25952, 207)
# (25952, 3)
#
#
# appended ef_ippu_tonne_ch2f2_per_mmm_gdp_product_use_ods_refrigeration
# (25952, 2)
# (25952, 208)
# (25952, 3)
#
#
# appended ef_ippu_tonne_ch2f2_per_tonne_production_chemicals
# (25952, 2)
# (25952, 209)
# (25952, 3)
#
#
# appended ef_ippu_tonne_ch2f2_per_tonne_production_electronics
# (25952, 2)
# (25952, 210)
# (25952, 3)
#
#
# appended ef_ippu_tonne_c4h5f5_per_mmm_gdp_product_use_ods_other
# (25952, 2)
# (25952, 211)
# (25952, 3)
#
#
# appended ef_ippu_tonne_c4h5f5_per_tonne_production_chemicals
# (25952, 2)
# (25952, 212)
# (25952, 3)
#
#
# appended ef_ippu_tonne_ch3f_per_tonne_production_electronics
# (25952, 2)
# (25952, 213)
# (25952, 3)
#
#
# appended ef_ippu_tonne_c5h2f10_per_mmm_gdp_product_use_ods_other
# (25952, 2)
# (25952, 214)
# (25952, 3)
#
#
# appended prodinit_ippu_cement_tonne
# (25952, 2)
# (25952, 215)
# (25952, 3)
#
#
# appended prodinit_ippu_chemicals_tonne
# (25952, 2)
# (25952, 216)
# (25952, 3)
#
#
# appended prodinit_ippu_electronics_tonne
# (25952, 2)
# (25952, 217)
# (25952, 3)
#
#
# appended prodinit_ippu_glass_tonne
# (25952, 2)
# (25952, 218)
# (25952, 3)
#
#
# appended prodinit_ippu_lime_and_carbonite_tonne
# (25952, 2)
# (25952, 219)
# (25952, 3)
#
#
# appended prodinit_ippu_metals_tonne
# (25952, 2)
# (25952, 220)
# (25952, 3)
#
#
# appended prodinit_ippu_mining_tonne
# (25952, 2)
# (25952, 221)
# (25952, 3)
#
#
# appended prodinit_ippu_paper_tonne
# (25952, 2)
# (25952, 222)
# (25952, 3)
#
#
# appended prodinit_ippu_plastic_tonne
# (25952, 2)
# (25952, 223)
# (25952, 3)
#
#
# appended prodinit_ippu_rubber_and_leather_tonne
# (25952, 2)
# (25952, 224)
# (25952, 3)
#
#
# appended prodinit_ippu_textiles_tonne
# (25952, 2)
# (25952, 225)
# (25952, 3)
#
#
# appended net_imports_cement_clinker_tonne
# (26307, 2)
# (26307, 226)
# (26307, 3)
#
#
# appended ef_ippu_tonne_c2f6_per_mmm_gdp_product_use_ods_other
# (26307, 2)
# (26307, 227)
# (26307, 3)
#
#
# appended ef_ippu_tonne_c2f6_per_tonne_production_chemicals
# (26307, 2)
# (26307, 228)
# (26307, 3)
#
#
# appended ef_ippu_tonne_c2f6_per_tonne_production_electronics
# (26307, 2)
# (26307, 229)
# (26307, 3)
#
#
# appended ef_ippu_tonne_c2f6_per_tonne_production_metals
# (26307, 2)
# (26307, 230)
# (26307, 3)
#
#
# appended ef_ippu_tonne_cf4_per_mmm_gdp_product_use_ods_other
# (26307, 2)
# (26307, 231)
# (26307, 3)
#
#
# appended ef_ippu_tonne_cf4_per_tonne_production_chemicals
# (26307, 2)
# (26307, 232)
# (26307, 3)
#
#
# appended ef_ippu_tonne_cf4_per_tonne_production_electronics
# (26307, 2)
# (26307, 233)
# (26307, 3)
#
#
# appended ef_ippu_tonne_cf4_per_tonne_production_metals
# (26307, 2)
# (26307, 234)
# (26307, 3)
#
#
# appended ef_ippu_tonne_c3f8_per_tonne_production_chemicals
# (26307, 2)
# (26307, 235)
# (26307, 3)
#
#
# appended ef_ippu_tonne_c3f8_per_tonne_production_electronics
# (26307, 2)
# (26307, 236)
# (26307, 3)
#
#
# appended ef_ippu_tonne_c4f10_per_mmm_gdp_product_use_ods_other
# (26307, 2)
# (26307, 237)
# (26307, 3)
#
#
# appended ef_ippu_tonne_c4f10_per_tonne_production_chemicals
# (26307, 2)
# (26307, 238)
# (26307, 3)
#
#
# appended ef_ippu_tonne_c6f14_per_mmm_gdp_product_use_ods_other
# (26307, 2)
# (26307, 239)
# (26307, 3)
#
#
# appended ef_ippu_tonne_c6f14_per_tonne_production_chemicals
# (26307, 2)
# (26307, 240)
# (26307, 3)
#
#
# appended ef_ippu_tonne_cc4f8_per_tonne_production_chemicals
# (26307, 2)
# (26307, 241)
# (26307, 3)
#
#
# appended ef_ippu_tonne_cc4f8_per_tonne_production_electronics
# (26307, 2)
# (26307, 242)
# (26307, 3)
#
#
# appended frac_inen_energy_agriculture_and_livestock_coal
# (26307, 2)
# (26307, 243)
# (26307, 3)
#
#
# appended frac_inen_energy_cement_coal
# (26307, 2)
# (26307, 244)
# (26307, 3)
#
#
# appended frac_inen_energy_chemicals_coal
# (26307, 2)
# (26307, 245)
# (26307, 3)
#
#
# appended frac_inen_energy_electronics_coal
# (26307, 2)
# (26307, 246)
# (26307, 3)
#
#
# appended frac_inen_energy_glass_coal
# (26307, 2)
# (26307, 247)
# (26307, 3)
#
#
# appended frac_inen_energy_lime_and_carbonite_coal
# (26307, 2)
# (26307, 248)
# (26307, 3)
#
#
# appended frac_inen_energy_metals_coal
# (26307, 2)
# (26307, 249)
# (26307, 3)
#
#
# appended frac_inen_energy_other_product_manufacturing_coal
# (26307, 2)
# (26307, 250)
# (26307, 3)
#
#
# appended frac_inen_energy_paper_coal
# (26307, 2)
# (26307, 251)
# (26307, 3)
#
#
# appended frac_inen_energy_plastic_coal
# (26307, 2)
# (26307, 252)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_glass_coal
# (26307, 2)
# (26307, 253)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_metals_coal
# (26307, 2)
# (26307, 254)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_paper_coal
# (26307, 2)
# (26307, 255)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_plastic_coal
# (26307, 2)
# (26307, 256)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_rubber_and_leather_coal
# (26307, 2)
# (26307, 257)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_textiles_coal
# (26307, 2)
# (26307, 258)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_wood_coal
# (26307, 2)
# (26307, 259)
# (26307, 3)
#
#
# appended frac_inen_energy_rubber_and_leather_coal
# (26307, 2)
# (26307, 260)
# (26307, 3)
#
#
# appended frac_inen_energy_textiles_coal
# (26307, 2)
# (26307, 261)
# (26307, 3)
#
#
# appended frac_inen_energy_wood_coal
# (26307, 2)
# (26307, 262)
# (26307, 3)
#
#
# appended frac_inen_energy_agriculture_and_livestock_coke
# (26307, 2)
# (26307, 263)
# (26307, 3)
#
#
# appended frac_inen_energy_cement_coke
# (26307, 2)
# (26307, 264)
# (26307, 3)
#
#
# appended frac_inen_energy_chemicals_coke
# (26307, 2)
# (26307, 265)
# (26307, 3)
#
#
# appended frac_inen_energy_electronics_coke
# (26307, 2)
# (26307, 266)
# (26307, 3)
#
#
# appended frac_inen_energy_glass_coke
# (26307, 2)
# (26307, 267)
# (26307, 3)
#
#
# appended frac_inen_energy_lime_and_carbonite_coke
# (26307, 2)
# (26307, 268)
# (26307, 3)
#
#
# appended frac_inen_energy_metals_coke
# (26307, 2)
# (26307, 269)
# (26307, 3)
#
#
# appended frac_inen_energy_other_product_manufacturing_coke
# (26307, 2)
# (26307, 270)
# (26307, 3)
#
#
# appended frac_inen_energy_paper_coke
# (26307, 2)
# (26307, 271)
# (26307, 3)
#
#
# appended frac_inen_energy_plastic_coke
# (26307, 2)
# (26307, 272)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_glass_coke
# (26307, 2)
# (26307, 273)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_metals_coke
# (26307, 2)
# (26307, 274)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_paper_coke
# (26307, 2)
# (26307, 275)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_plastic_coke
# (26307, 2)
# (26307, 276)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_rubber_and_leather_coke
# (26307, 2)
# (26307, 277)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_textiles_coke
# (26307, 2)
# (26307, 278)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_wood_coke
# (26307, 2)
# (26307, 279)
# (26307, 3)
#
#
# appended frac_inen_energy_rubber_and_leather_coke
# (26307, 2)
# (26307, 280)
# (26307, 3)
#
#
# appended frac_inen_energy_textiles_coke
# (26307, 2)
# (26307, 281)
# (26307, 3)
#
#
# appended frac_inen_energy_wood_coke
# (26307, 2)
# (26307, 282)
# (26307, 3)
#
#
# appended frac_inen_energy_agriculture_and_livestock_diesel
# (26307, 2)
# (26307, 283)
# (26307, 3)
#
#
# appended frac_inen_energy_cement_diesel
# (26307, 2)
# (26307, 284)
# (26307, 3)
#
#
# appended frac_inen_energy_chemicals_diesel
# (26307, 2)
# (26307, 285)
# (26307, 3)
#
#
# appended frac_inen_energy_electronics_diesel
# (26307, 2)
# (26307, 286)
# (26307, 3)
#
#
# appended frac_inen_energy_glass_diesel
# (26307, 2)
# (26307, 287)
# (26307, 3)
#
#
# appended frac_inen_energy_lime_and_carbonite_diesel
# (26307, 2)
# (26307, 288)
# (26307, 3)
#
#
# appended frac_inen_energy_metals_diesel
# (26307, 2)
# (26307, 289)
# (26307, 3)
#
#
# appended frac_inen_energy_other_product_manufacturing_diesel
# (26307, 2)
# (26307, 290)
# (26307, 3)
#
#
# appended frac_inen_energy_paper_diesel
# (26307, 2)
# (26307, 291)
# (26307, 3)
#
#
# appended frac_inen_energy_plastic_diesel
# (26307, 2)
# (26307, 292)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_glass_diesel
# (26307, 2)
# (26307, 293)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_metals_diesel
# (26307, 2)
# (26307, 294)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_paper_diesel
# (26307, 2)
# (26307, 295)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_plastic_diesel
# (26307, 2)
# (26307, 296)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_rubber_and_leather_diesel
# (26307, 2)
# (26307, 297)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_textiles_diesel
# (26307, 2)
# (26307, 298)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_wood_diesel
# (26307, 2)
# (26307, 299)
# (26307, 3)
#
#
# appended frac_inen_energy_rubber_and_leather_diesel
# (26307, 2)
# (26307, 300)
# (26307, 3)
#
#
# appended frac_inen_energy_textiles_diesel
# (26307, 2)
# (26307, 301)
# (26307, 3)
#
#
# appended frac_inen_energy_wood_diesel
# (26307, 2)
# (26307, 302)
# (26307, 3)
#
#
# appended frac_inen_energy_agriculture_and_livestock_electricity
# (26307, 2)
# (26307, 303)
# (26307, 3)
#
#
# appended frac_inen_energy_cement_electricity
# (26307, 2)
# (26307, 304)
# (26307, 3)
#
#
# appended frac_inen_energy_chemicals_electricity
# (26307, 2)
# (26307, 305)
# (26307, 3)
#
#
# appended frac_inen_energy_electronics_electricity
# (26307, 2)
# (26307, 306)
# (26307, 3)
#
#
# appended frac_inen_energy_glass_electricity
# (26307, 2)
# (26307, 307)
# (26307, 3)
#
#
# appended frac_inen_energy_lime_and_carbonite_electricity
# (26307, 2)
# (26307, 308)
# (26307, 3)
#
#
# appended frac_inen_energy_metals_electricity
# (26307, 2)
# (26307, 309)
# (26307, 3)
#
#
# appended frac_inen_energy_other_product_manufacturing_electricity
# (26307, 2)
# (26307, 310)
# (26307, 3)
#
#
# appended frac_inen_energy_paper_electricity
# (26307, 2)
# (26307, 311)
# (26307, 3)
#
#
# appended frac_inen_energy_plastic_electricity
# (26307, 2)
# (26307, 312)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_glass_electricity
# (26307, 2)
# (26307, 313)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_metals_electricity
# (26307, 2)
# (26307, 314)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_paper_electricity
# (26307, 2)
# (26307, 315)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_plastic_electricity
# (26307, 2)
# (26307, 316)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_rubber_and_leather_electricity
# (26307, 2)
# (26307, 317)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_textiles_electricity
# (26307, 2)
# (26307, 318)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_wood_electricity
# (26307, 2)
# (26307, 319)
# (26307, 3)
#
#
# appended frac_inen_energy_rubber_and_leather_electricity
# (26307, 2)
# (26307, 320)
# (26307, 3)
#
#
# appended frac_inen_energy_textiles_electricity
# (26307, 2)
# (26307, 321)
# (26307, 3)
#
#
# appended frac_inen_energy_wood_electricity
# (26307, 2)
# (26307, 322)
# (26307, 3)
#
#
# appended frac_inen_energy_agriculture_and_livestock_furnace_gas
# (26307, 2)
# (26307, 323)
# (26307, 3)
#
#
# appended frac_inen_energy_cement_furnace_gas
# (26307, 2)
# (26307, 324)
# (26307, 3)
#
#
# appended frac_inen_energy_chemicals_furnace_gas
# (26307, 2)
# (26307, 325)
# (26307, 3)
#
#
# appended frac_inen_energy_electronics_furnace_gas
# (26307, 2)
# (26307, 326)
# (26307, 3)
#
#
# appended frac_inen_energy_glass_furnace_gas
# (26307, 2)
# (26307, 327)
# (26307, 3)
#
#
# appended frac_inen_energy_lime_and_carbonite_furnace_gas
# (26307, 2)
# (26307, 328)
# (26307, 3)
#
#
# appended frac_inen_energy_metals_furnace_gas
# (26307, 2)
# (26307, 329)
# (26307, 3)
#
#
# appended frac_inen_energy_other_product_manufacturing_furnace_gas
# (26307, 2)
# (26307, 330)
# (26307, 3)
#
#
# appended frac_inen_energy_paper_furnace_gas
# (26307, 2)
# (26307, 331)
# (26307, 3)
#
#
# appended frac_inen_energy_plastic_furnace_gas
# (26307, 2)
# (26307, 332)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_glass_furnace_gas
# (26307, 2)
# (26307, 333)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_metals_furnace_gas
# (26307, 2)
# (26307, 334)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_paper_furnace_gas
# (26307, 2)
# (26307, 335)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_plastic_furnace_gas
# (26307, 2)
# (26307, 336)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_rubber_and_leather_furnace_gas
# (26307, 2)
# (26307, 337)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_textiles_furnace_gas
# (26307, 2)
# (26307, 338)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_wood_furnace_gas
# (26307, 2)
# (26307, 339)
# (26307, 3)
#
#
# appended frac_inen_energy_rubber_and_leather_furnace_gas
# (26307, 2)
# (26307, 340)
# (26307, 3)
#
#
# appended frac_inen_energy_textiles_furnace_gas
# (26307, 2)
# (26307, 341)
# (26307, 3)
#
#
# appended frac_inen_energy_wood_furnace_gas
# (26307, 2)
# (26307, 342)
# (26307, 3)
#
#
# appended frac_inen_energy_agriculture_and_livestock_gasoline
# (26307, 2)
# (26307, 343)
# (26307, 3)
#
#
# appended frac_inen_energy_cement_gasoline
# (26307, 2)
# (26307, 344)
# (26307, 3)
#
#
# appended frac_inen_energy_chemicals_gasoline
# (26307, 2)
# (26307, 345)
# (26307, 3)
#
#
# appended frac_inen_energy_electronics_gasoline
# (26307, 2)
# (26307, 346)
# (26307, 3)
#
#
# appended frac_inen_energy_glass_gasoline
# (26307, 2)
# (26307, 347)
# (26307, 3)
#
#
# appended frac_inen_energy_lime_and_carbonite_gasoline
# (26307, 2)
# (26307, 348)
# (26307, 3)
#
#
# appended frac_inen_energy_metals_gasoline
# (26307, 2)
# (26307, 349)
# (26307, 3)
#
#
# appended frac_inen_energy_other_product_manufacturing_gasoline
# (26307, 2)
# (26307, 350)
# (26307, 3)
#
#
# appended frac_inen_energy_paper_gasoline
# (26307, 2)
# (26307, 351)
# (26307, 3)
#
#
# appended frac_inen_energy_plastic_gasoline
# (26307, 2)
# (26307, 352)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_glass_gasoline
# (26307, 2)
# (26307, 353)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_metals_gasoline
# (26307, 2)
# (26307, 354)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_paper_gasoline
# (26307, 2)
# (26307, 355)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_plastic_gasoline
# (26307, 2)
# (26307, 356)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_rubber_and_leather_gasoline
# (26307, 2)
# (26307, 357)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_textiles_gasoline
# (26307, 2)
# (26307, 358)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_wood_gasoline
# (26307, 2)
# (26307, 359)
# (26307, 3)
#
#
# appended frac_inen_energy_rubber_and_leather_gasoline
# (26307, 2)
# (26307, 360)
# (26307, 3)
#
#
# appended frac_inen_energy_textiles_gasoline
# (26307, 2)
# (26307, 361)
# (26307, 3)
#
#
# appended frac_inen_energy_wood_gasoline
# (26307, 2)
# (26307, 362)
# (26307, 3)
#
#
# appended frac_inen_energy_agriculture_and_livestock_hydrocarbon_gas_liquids
# (26307, 2)
# (26307, 363)
# (26307, 3)
#
#
# appended frac_inen_energy_cement_hydrocarbon_gas_liquids
# (26307, 2)
# (26307, 364)
# (26307, 3)
#
#
# appended frac_inen_energy_chemicals_hydrocarbon_gas_liquids
# (26307, 2)
# (26307, 365)
# (26307, 3)
#
#
# appended frac_inen_energy_electronics_hydrocarbon_gas_liquids
# (26307, 2)
# (26307, 366)
# (26307, 3)
#
#
# appended frac_inen_energy_glass_hydrocarbon_gas_liquids
# (26307, 2)
# (26307, 367)
# (26307, 3)
#
#
# appended frac_inen_energy_lime_and_carbonite_hydrocarbon_gas_liquids
# (26307, 2)
# (26307, 368)
# (26307, 3)
#
#
# appended frac_inen_energy_metals_hydrocarbon_gas_liquids
# (26307, 2)
# (26307, 369)
# (26307, 3)
#
#
# appended frac_inen_energy_other_product_manufacturing_hydrocarbon_gas_liquids
# (26307, 2)
# (26307, 370)
# (26307, 3)
#
#
# appended frac_inen_energy_paper_hydrocarbon_gas_liquids
# (26307, 2)
# (26307, 371)
# (26307, 3)
#
#
# appended frac_inen_energy_plastic_hydrocarbon_gas_liquids
# (26307, 2)
# (26307, 372)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_glass_hydrocarbon_gas_liquids
# (26307, 2)
# (26307, 373)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_metals_hydrocarbon_gas_liquids
# (26307, 2)
# (26307, 374)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_paper_hydrocarbon_gas_liquids
# (26307, 2)
# (26307, 375)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_plastic_hydrocarbon_gas_liquids
# (26307, 2)
# (26307, 376)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_rubber_and_leather_hydrocarbon_gas_liquids
# (26307, 2)
# (26307, 377)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_textiles_hydrocarbon_gas_liquids
# (26307, 2)
# (26307, 378)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_wood_hydrocarbon_gas_liquids
# (26307, 2)
# (26307, 379)
# (26307, 3)
#
#
# appended frac_inen_energy_rubber_and_leather_hydrocarbon_gas_liquids
# (26307, 2)
# (26307, 380)
# (26307, 3)
#
#
# appended frac_inen_energy_textiles_hydrocarbon_gas_liquids
# (26307, 2)
# (26307, 381)
# (26307, 3)
#
#
# appended frac_inen_energy_wood_hydrocarbon_gas_liquids
# (26307, 2)
# (26307, 382)
# (26307, 3)
#
#
# appended frac_inen_energy_agriculture_and_livestock_hydrogen
# (26307, 2)
# (26307, 383)
# (26307, 3)
#
#
# appended frac_inen_energy_cement_hydrogen
# (26307, 2)
# (26307, 384)
# (26307, 3)
#
#
# appended frac_inen_energy_chemicals_hydrogen
# (26307, 2)
# (26307, 385)
# (26307, 3)
#
#
# appended frac_inen_energy_electronics_hydrogen
# (26307, 2)
# (26307, 386)
# (26307, 3)
#
#
# appended frac_inen_energy_glass_hydrogen
# (26307, 2)
# (26307, 387)
# (26307, 3)
#
#
# appended frac_inen_energy_lime_and_carbonite_hydrogen
# (26307, 2)
# (26307, 388)
# (26307, 3)
#
#
# appended frac_inen_energy_metals_hydrogen
# (26307, 2)
# (26307, 389)
# (26307, 3)
#
#
# appended frac_inen_energy_other_product_manufacturing_hydrogen
# (26307, 2)
# (26307, 390)
# (26307, 3)
#
#
# appended frac_inen_energy_paper_hydrogen
# (26307, 2)
# (26307, 391)
# (26307, 3)
#
#
# appended frac_inen_energy_plastic_hydrogen
# (26307, 2)
# (26307, 392)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_glass_hydrogen
# (26307, 2)
# (26307, 393)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_metals_hydrogen
# (26307, 2)
# (26307, 394)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_paper_hydrogen
# (26307, 2)
# (26307, 395)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_plastic_hydrogen
# (26307, 2)
# (26307, 396)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_rubber_and_leather_hydrogen
# (26307, 2)
# (26307, 397)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_textiles_hydrogen
# (26307, 2)
# (26307, 398)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_wood_hydrogen
# (26307, 2)
# (26307, 399)
# (26307, 3)
#
#
# appended frac_inen_energy_rubber_and_leather_hydrogen
# (26307, 2)
# (26307, 400)
# (26307, 3)
#
#
# appended frac_inen_energy_textiles_hydrogen
# (26307, 2)
# (26307, 401)
# (26307, 3)
#
#
# appended frac_inen_energy_wood_hydrogen
# (26307, 2)
# (26307, 402)
# (26307, 3)
#
#
# appended frac_inen_energy_agriculture_and_livestock_kerosene
# (26307, 2)
# (26307, 403)
# (26307, 3)
#
#
# appended frac_inen_energy_cement_kerosene
# (26307, 2)
# (26307, 404)
# (26307, 3)
#
#
# appended frac_inen_energy_chemicals_kerosene
# (26307, 2)
# (26307, 405)
# (26307, 3)
#
#
# appended frac_inen_energy_electronics_kerosene
# (26307, 2)
# (26307, 406)
# (26307, 3)
#
#
# appended frac_inen_energy_glass_kerosene
# (26307, 2)
# (26307, 407)
# (26307, 3)
#
#
# appended frac_inen_energy_lime_and_carbonite_kerosene
# (26307, 2)
# (26307, 408)
# (26307, 3)
#
#
# appended frac_inen_energy_metals_kerosene
# (26307, 2)
# (26307, 409)
# (26307, 3)
#
#
# appended frac_inen_energy_other_product_manufacturing_kerosene
# (26307, 2)
# (26307, 410)
# (26307, 3)
#
#
# appended frac_inen_energy_paper_kerosene
# (26307, 2)
# (26307, 411)
# (26307, 3)
#
#
# appended frac_inen_energy_plastic_kerosene
# (26307, 2)
# (26307, 412)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_glass_kerosene
# (26307, 2)
# (26307, 413)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_metals_kerosene
# (26307, 2)
# (26307, 414)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_paper_kerosene
# (26307, 2)
# (26307, 415)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_plastic_kerosene
# (26307, 2)
# (26307, 416)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_rubber_and_leather_kerosene
# (26307, 2)
# (26307, 417)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_textiles_kerosene
# (26307, 2)
# (26307, 418)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_wood_kerosene
# (26307, 2)
# (26307, 419)
# (26307, 3)
#
#
# appended frac_inen_energy_rubber_and_leather_kerosene
# (26307, 2)
# (26307, 420)
# (26307, 3)
#
#
# appended frac_inen_energy_textiles_kerosene
# (26307, 2)
# (26307, 421)
# (26307, 3)
#
#
# appended frac_inen_energy_wood_kerosene
# (26307, 2)
# (26307, 422)
# (26307, 3)
#
#
# appended frac_inen_energy_agriculture_and_livestock_natural_gas
# (26307, 2)
# (26307, 423)
# (26307, 3)
#
#
# appended frac_inen_energy_cement_natural_gas
# (26307, 2)
# (26307, 424)
# (26307, 3)
#
#
# appended frac_inen_energy_chemicals_natural_gas
# (26307, 2)
# (26307, 425)
# (26307, 3)
#
#
# appended frac_inen_energy_electronics_natural_gas
# (26307, 2)
# (26307, 426)
# (26307, 3)
#
#
# appended frac_inen_energy_glass_natural_gas
# (26307, 2)
# (26307, 427)
# (26307, 3)
#
#
# appended frac_inen_energy_lime_and_carbonite_natural_gas
# (26307, 2)
# (26307, 428)
# (26307, 3)
#
#
# appended frac_inen_energy_metals_natural_gas
# (26307, 2)
# (26307, 429)
# (26307, 3)
#
#
# appended frac_inen_energy_other_product_manufacturing_natural_gas
# (26307, 2)
# (26307, 430)
# (26307, 3)
#
#
# appended frac_inen_energy_paper_natural_gas
# (26307, 2)
# (26307, 431)
# (26307, 3)
#
#
# appended frac_inen_energy_plastic_natural_gas
# (26307, 2)
# (26307, 432)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_glass_natural_gas
# (26307, 2)
# (26307, 433)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_metals_natural_gas
# (26307, 2)
# (26307, 434)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_paper_natural_gas
# (26307, 2)
# (26307, 435)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_plastic_natural_gas
# (26307, 2)
# (26307, 436)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_rubber_and_leather_natural_gas
# (26307, 2)
# (26307, 437)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_textiles_natural_gas
# (26307, 2)
# (26307, 438)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_wood_natural_gas
# (26307, 2)
# (26307, 439)
# (26307, 3)
#
#
# appended frac_inen_energy_rubber_and_leather_natural_gas
# (26307, 2)
# (26307, 440)
# (26307, 3)
#
#
# appended frac_inen_energy_textiles_natural_gas
# (26307, 2)
# (26307, 441)
# (26307, 3)
#
#
# appended frac_inen_energy_wood_natural_gas
# (26307, 2)
# (26307, 442)
# (26307, 3)
#
#
# appended frac_inen_energy_agriculture_and_livestock_oil
# (26307, 2)
# (26307, 443)
# (26307, 3)
#
#
# appended frac_inen_energy_cement_oil
# (26307, 2)
# (26307, 444)
# (26307, 3)
#
#
# appended frac_inen_energy_chemicals_oil
# (26307, 2)
# (26307, 445)
# (26307, 3)
#
#
# appended frac_inen_energy_electronics_oil
# (26307, 2)
# (26307, 446)
# (26307, 3)
#
#
# appended frac_inen_energy_glass_oil
# (26307, 2)
# (26307, 447)
# (26307, 3)
#
#
# appended frac_inen_energy_lime_and_carbonite_oil
# (26307, 2)
# (26307, 448)
# (26307, 3)
#
#
# appended frac_inen_energy_metals_oil
# (26307, 2)
# (26307, 449)
# (26307, 3)
#
#
# appended frac_inen_energy_other_product_manufacturing_oil
# (26307, 2)
# (26307, 450)
# (26307, 3)
#
#
# appended frac_inen_energy_paper_oil
# (26307, 2)
# (26307, 451)
# (26307, 3)
#
#
# appended frac_inen_energy_plastic_oil
# (26307, 2)
# (26307, 452)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_glass_oil
# (26307, 2)
# (26307, 453)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_metals_oil
# (26307, 2)
# (26307, 454)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_paper_oil
# (26307, 2)
# (26307, 455)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_plastic_oil
# (26307, 2)
# (26307, 456)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_rubber_and_leather_oil
# (26307, 2)
# (26307, 457)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_textiles_oil
# (26307, 2)
# (26307, 458)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_wood_oil
# (26307, 2)
# (26307, 459)
# (26307, 3)
#
#
# appended frac_inen_energy_rubber_and_leather_oil
# (26307, 2)
# (26307, 460)
# (26307, 3)
#
#
# appended frac_inen_energy_textiles_oil
# (26307, 2)
# (26307, 461)
# (26307, 3)
#
#
# appended frac_inen_energy_wood_oil
# (26307, 2)
# (26307, 462)
# (26307, 3)
#
#
# appended frac_inen_energy_agriculture_and_livestock_solar
# (26307, 2)
# (26307, 463)
# (26307, 3)
#
#
# appended frac_inen_energy_cement_solar
# (26307, 2)
# (26307, 464)
# (26307, 3)
#
#
# appended frac_inen_energy_chemicals_solar
# (26307, 2)
# (26307, 465)
# (26307, 3)
#
#
# appended frac_inen_energy_electronics_solar
# (26307, 2)
# (26307, 466)
# (26307, 3)
#
#
# appended frac_inen_energy_glass_solar
# (26307, 2)
# (26307, 467)
# (26307, 3)
#
#
# appended frac_inen_energy_lime_and_carbonite_solar
# (26307, 2)
# (26307, 468)
# (26307, 3)
#
#
# appended frac_inen_energy_metals_solar
# (26307, 2)
# (26307, 469)
# (26307, 3)
#
#
# appended frac_inen_energy_other_product_manufacturing_solar
# (26307, 2)
# (26307, 470)
# (26307, 3)
#
#
# appended frac_inen_energy_paper_solar
# (26307, 2)
# (26307, 471)
# (26307, 3)
#
#
# appended frac_inen_energy_plastic_solar
# (26307, 2)
# (26307, 472)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_glass_solar
# (26307, 2)
# (26307, 473)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_metals_solar
# (26307, 2)
# (26307, 474)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_paper_solar
# (26307, 2)
# (26307, 475)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_plastic_solar
# (26307, 2)
# (26307, 476)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_rubber_and_leather_solar
# (26307, 2)
# (26307, 477)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_textiles_solar
# (26307, 2)
# (26307, 478)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_wood_solar
# (26307, 2)
# (26307, 479)
# (26307, 3)
#
#
# appended frac_inen_energy_rubber_and_leather_solar
# (26307, 2)
# (26307, 480)
# (26307, 3)
#
#
# appended frac_inen_energy_textiles_solar
# (26307, 2)
# (26307, 481)
# (26307, 3)
#
#
# appended frac_inen_energy_wood_solar
# (26307, 2)
# (26307, 482)
# (26307, 3)
#
#
# appended frac_inen_energy_agriculture_and_livestock_solid_biomass
# (26307, 2)
# (26307, 483)
# (26307, 3)
#
#
# appended frac_inen_energy_cement_solid_biomass
# (26307, 2)
# (26307, 484)
# (26307, 3)
#
#
# appended frac_inen_energy_chemicals_solid_biomass
# (26307, 2)
# (26307, 485)
# (26307, 3)
#
#
# appended frac_inen_energy_electronics_solid_biomass
# (26307, 2)
# (26307, 486)
# (26307, 3)
#
#
# appended frac_inen_energy_glass_solid_biomass
# (26307, 2)
# (26307, 487)
# (26307, 3)
#
#
# appended frac_inen_energy_lime_and_carbonite_solid_biomass
# (26307, 2)
# (26307, 488)
# (26307, 3)
#
#
# appended frac_inen_energy_metals_solid_biomass
# (26307, 2)
# (26307, 489)
# (26307, 3)
#
#
# appended frac_inen_energy_other_product_manufacturing_solid_biomass
# (26307, 2)
# (26307, 490)
# (26307, 3)
#
#
# appended frac_inen_energy_paper_solid_biomass
# (26307, 2)
# (26307, 491)
# (26307, 3)
#
#
# appended frac_inen_energy_plastic_solid_biomass
# (26307, 2)
# (26307, 492)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_glass_solid_biomass
# (26307, 2)
# (26307, 493)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_metals_solid_biomass
# (26307, 2)
# (26307, 494)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_paper_solid_biomass
# (26307, 2)
# (26307, 495)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_plastic_solid_biomass
# (26307, 2)
# (26307, 496)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_rubber_and_leather_solid_biomass
# (26307, 2)
# (26307, 497)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_textiles_solid_biomass
# (26307, 2)
# (26307, 498)
# (26307, 3)
#
#
# appended frac_inen_energy_recycled_wood_solid_biomass
# (26307, 2)
# (26307, 499)
# (26307, 3)
#
#
# appended frac_inen_energy_rubber_and_leather_solid_biomass
# (26307, 2)
# (26307, 500)
# (26307, 3)
#
#
# appended frac_inen_energy_textiles_solid_biomass
# (26307, 2)
# (26307, 501)
# (26307, 3)
#
#
# appended frac_inen_energy_wood_solid_biomass
# (26307, 2)
# (26307, 502)
# (26307, 3)
#
#
# appended consumpinit_inen_energy_tj_per_mmm_gdp_other_product_manufacturing
# (26307, 2)
# (26307, 503)
# (26307, 3)
#
#
# appended consumpinit_inen_energy_tj_per_tonne_production_cement
# (26307, 2)
# (26307, 504)
# (26307, 3)
#
#
# appended consumpinit_inen_energy_tj_per_tonne_production_chemicals
# (26307, 2)
# (26307, 505)
# (26307, 3)
#
#
# appended consumpinit_inen_energy_tj_per_tonne_production_electronics
# (26307, 2)
# (26307, 506)
# (26307, 3)
#
#
# appended consumpinit_inen_energy_tj_per_tonne_production_glass
# (26307, 2)
# (26307, 507)
# (26307, 3)
#
#
# appended consumpinit_inen_energy_tj_per_tonne_production_lime_and_carbonite
# (26307, 2)
# (26307, 508)
# (26307, 3)
#
#
# appended consumpinit_inen_energy_tj_per_tonne_production_metals
# (26307, 2)
# (26307, 509)
# (26307, 3)
#
#
# appended consumpinit_inen_energy_tj_per_tonne_production_mining
# (26307, 2)
# (26307, 510)
# (26307, 3)
#
#
# appended consumpinit_inen_energy_tj_per_tonne_production_paper
# (26307, 2)
# (26307, 511)
# (26307, 3)
#
#
# appended consumpinit_inen_energy_tj_per_tonne_production_plastic
# (26307, 2)
# (26307, 512)
# (26307, 3)
#
#
# appended consumpinit_inen_energy_tj_per_tonne_production_recycled_glass
# (26307, 2)
# (26307, 513)
# (26307, 3)
#
#
# appended consumpinit_inen_energy_tj_per_tonne_production_recycled_metals
# (26307, 2)
# (26307, 514)
# (26307, 3)
#
#
# appended consumpinit_inen_energy_tj_per_tonne_production_recycled_paper
# (26307, 2)
# (26307, 515)
# (26307, 3)
#
#
# appended consumpinit_inen_energy_tj_per_tonne_production_recycled_plastic
# (26307, 2)
# (26307, 516)
# (26307, 3)
#
#
# appended consumpinit_inen_energy_tj_per_tonne_production_recycled_rubber_and_leather
# (26307, 2)
# (26307, 517)
# (26307, 3)
#
#
# appended consumpinit_inen_energy_tj_per_tonne_production_recycled_textiles
# (26307, 2)
# (26307, 518)
# (26307, 3)
#
#
# appended consumpinit_inen_energy_tj_per_tonne_production_recycled_wood
# (26307, 2)
# (26307, 519)
# (26307, 3)
#
#
# appended consumpinit_inen_energy_tj_per_tonne_production_rubber_and_leather
# (26307, 2)
# (26307, 520)
# (26307, 3)
#
#
# appended consumpinit_inen_energy_tj_per_tonne_production_textiles
# (26307, 2)
# (26307, 521)
# (26307, 3)
#
#
# appended consumpinit_inen_energy_tj_per_tonne_production_wood
# (26307, 2)
# (26307, 522)
# (26307, 3)
#
#
# appended consumpinit_inen_energy_total_pj_agriculture_and_livestock
# (26307, 2)
# (26307, 523)
# (26307, 3)
#
#
# appended frac_lndu_initial_croplands
# (26307, 2)
# (26307, 524)
# (26307, 3)
#
#
# appended frac_lndu_initial_forests_mangroves
# (26307, 2)
# (26307, 525)
# (26307, 3)
#
#
# appended frac_lndu_initial_forests_primary
# (26307, 2)
# (26307, 526)
# (26307, 3)
#
#
# appended frac_lndu_initial_forests_secondary
# (26307, 2)
# (26307, 527)
# (26307, 3)
#
#
# appended frac_lndu_initial_grasslands
# (26307, 2)
# (26307, 528)
# (26307, 3)
#
#
# appended frac_lndu_initial_other
# (26307, 2)
# (26307, 529)
# (26307, 3)
#
#
# appended frac_lndu_initial_settlements
# (26307, 2)
# (26307, 530)
# (26307, 3)
#
#
# appended frac_lndu_initial_wetlands
# (26307, 2)
# (26307, 531)
# (26307, 3)
#
#
# appended frac_lndu_grasslands_cl2_dry
# (26307, 2)
# (26307, 532)
# (26307, 3)
#
#
# appended frac_lndu_other_cl2_dry
# (26307, 2)
# (26307, 533)
# (26307, 3)
#
#
# appended frac_lndu_settlements_cl2_dry
# (26307, 2)
# (26307, 534)
# (26307, 3)
#
#
# appended frac_lndu_grasslands_cl1_temperate
# (26307, 2)
# (26307, 535)
# (26307, 3)
#
#
# appended frac_lndu_grasslands_cl1_tropical
# (26307, 2)
# (26307, 536)
# (26307, 3)
#
#
# appended frac_lndu_grasslands_cl2_wet
# (26307, 2)
# (26307, 537)
# (26307, 3)
#
#
# appended frac_lndu_other_cl2_wet
# (26307, 2)
# (26307, 538)
# (26307, 3)
#
#
# appended frac_lndu_settlements_cl2_wet
# (26307, 2)
# (26307, 539)
# (26307, 3)
#
#
# appended pij_lndu_croplands_to_croplands
# (26307, 2)
# (26307, 540)
# (26307, 3)
#
#
# appended pij_lndu_forests_mangroves_to_forests_mangroves
# (26307, 2)
# (26307, 541)
# (26307, 3)
#
#
# appended pij_lndu_forests_primary_to_forests_primary
# (26307, 2)
# (26307, 542)
# (26307, 3)
#
#
# appended pij_lndu_forests_secondary_to_forests_secondary
# (26307, 2)
# (26307, 543)
# (26307, 3)
#
#
# appended pij_lndu_grasslands_to_grasslands
# (26307, 2)
# (26307, 544)
# (26307, 3)
#
#
# appended pij_lndu_other_to_other
# (26307, 2)
# (26307, 545)
# (26307, 3)
#
#
# appended pij_lndu_settlements_to_settlements
# (26307, 2)
# (26307, 546)
# (26307, 3)
#
#
# appended pij_lndu_wetlands_to_wetlands
# (26307, 2)
# (26307, 547)
# (26307, 3)
#
#
# appended pop_lvst_initial_buffalo
# (26387, 2)
# (26387, 548)
# (26387, 3)
#
#
# appended pop_lvst_initial_cattle_dairy
# (26387, 2)
# (26387, 549)
# (26387, 3)
#
#
# appended pop_lvst_initial_cattle_nondairy
# (26387, 2)
# (26387, 550)
# (26387, 3)
#
#
# appended pop_lvst_initial_chickens
# (26387, 2)
# (26387, 551)
# (26387, 3)
#
#
# appended pop_lvst_initial_goats
# (26387, 2)
# (26387, 552)
# (26387, 3)
#
#
# appended pop_lvst_initial_horses
# (26387, 2)
# (26387, 553)
# (26387, 3)
#
#
# appended pop_lvst_initial_mules
# (26387, 2)
# (26387, 554)
# (26387, 3)
#
#
# appended pop_lvst_initial_pigs
# (26387, 2)
# (26387, 555)
# (26387, 3)
#
#
# appended pop_lvst_initial_sheep
# (26387, 2)
# (26387, 556)
# (26387, 3)
#
#
# appended qty_soil_organic_c_stock_dry_climate_tonne_per_ha
# (26387, 2)
# (26387, 557)
# (26387, 3)
#
#
# appended qty_soil_organic_c_stock_temperate_crop_grass_tonne_per_ha
# (26387, 2)
# (26387, 558)
# (26387, 3)
#
#
# appended qty_soil_organic_c_stock_temperate_forest_nutrient_poor_tonne_per_ha
# (26387, 2)
# (26387, 559)
# (26387, 3)
#
#
# appended qty_soil_organic_c_stock_temperate_forest_nutrient_rich_tonne_per_ha
# (26387, 2)
# (26387, 560)
# (26387, 3)
#
#
# appended qty_soil_organic_c_stock_tropical_crop_grass_tonne_per_ha
# (26387, 2)
# (26387, 561)
# (26387, 3)
#
#
# appended qty_soil_organic_c_stock_tropical_forest_tonne_per_ha
# (26387, 2)
# (26387, 562)
# (26387, 3)
#
#
# appended qty_soil_organic_c_stock_wet_climate_tonne_per_ha
# (26387, 2)
# (26387, 563)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_commercial_municipal_coal
# (26387, 2)
# (26387, 564)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_other_se_coal
# (26387, 2)
# (26387, 565)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_residential_coal
# (26387, 2)
# (26387, 566)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_commercial_municipal_diesel
# (26387, 2)
# (26387, 567)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_other_se_diesel
# (26387, 2)
# (26387, 568)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_residential_diesel
# (26387, 2)
# (26387, 569)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_commercial_municipal_electricity
# (26387, 2)
# (26387, 570)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_other_se_electricity
# (26387, 2)
# (26387, 571)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_residential_electricity
# (26387, 2)
# (26387, 572)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_commercial_municipal_gasoline
# (26387, 2)
# (26387, 573)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_other_se_gasoline
# (26387, 2)
# (26387, 574)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_residential_gasoline
# (26387, 2)
# (26387, 575)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_commercial_municipal_hydrogen
# (26387, 2)
# (26387, 576)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_other_se_hydrogen
# (26387, 2)
# (26387, 577)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_residential_hydrogen
# (26387, 2)
# (26387, 578)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_commercial_municipal_kerosene
# (26387, 2)
# (26387, 579)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_other_se_kerosene
# (26387, 2)
# (26387, 580)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_residential_kerosene
# (26387, 2)
# (26387, 581)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_commercial_municipal_natural_gas
# (26387, 2)
# (26387, 582)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_other_se_natural_gas
# (26387, 2)
# (26387, 583)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_residential_natural_gas
# (26387, 2)
# (26387, 584)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_commercial_municipal_solid_biomass
# (26387, 2)
# (26387, 585)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_other_se_solid_biomass
# (26387, 2)
# (26387, 586)
# (26387, 3)
#
#
# appended efficfactor_scoe_heat_energy_residential_solid_biomass
# (26387, 2)
# (26387, 587)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_commercial_municipal_coal
# (26387, 2)
# (26387, 588)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_other_se_coal
# (26387, 2)
# (26387, 589)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_residential_coal
# (26387, 2)
# (26387, 590)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_commercial_municipal_diesel
# (26387, 2)
# (26387, 591)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_other_se_diesel
# (26387, 2)
# (26387, 592)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_residential_diesel
# (26387, 2)
# (26387, 593)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_commercial_municipal_electricity
# (26387, 2)
# (26387, 594)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_other_se_electricity
# (26387, 2)
# (26387, 595)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_residential_electricity
# (26387, 2)
# (26387, 596)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_commercial_municipal_gasoline
# (26387, 2)
# (26387, 597)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_other_se_gasoline
# (26387, 2)
# (26387, 598)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_residential_gasoline
# (26387, 2)
# (26387, 599)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_commercial_municipal_hydrocarbon_gas_liquids
# (26387, 2)
# (26387, 600)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_other_se_hydrocarbon_gas_liquids
# (26387, 2)
# (26387, 601)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_residential_hydrocarbon_gas_liquids
# (26387, 2)
# (26387, 602)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_commercial_municipal_hydrogen
# (26387, 2)
# (26387, 603)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_other_se_hydrogen
# (26387, 2)
# (26387, 604)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_residential_hydrogen
# (26387, 2)
# (26387, 605)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_commercial_municipal_kerosene
# (26387, 2)
# (26387, 606)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_other_se_kerosene
# (26387, 2)
# (26387, 607)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_residential_kerosene
# (26387, 2)
# (26387, 608)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_commercial_municipal_natural_gas
# (26387, 2)
# (26387, 609)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_other_se_natural_gas
# (26387, 2)
# (26387, 610)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_residential_natural_gas
# (26387, 2)
# (26387, 611)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_commercial_municipal_solid_biomass
# (26387, 2)
# (26387, 612)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_other_se_solid_biomass
# (26387, 2)
# (26387, 613)
# (26387, 3)
#
#
# appended frac_scoe_heat_energy_residential_solid_biomass
# (26387, 2)
# (26387, 614)
# (26387, 3)
#
#
# appended consumpinit_scoe_tj_per_mmmgdp_commercial_municipal_elec_appliances
# (26387, 2)
# (26387, 615)
# (26387, 3)
#
#
# appended consumpinit_scoe_tj_per_mmmgdp_other_se_elec_appliances
# (26387, 2)
# (26387, 616)
# (26387, 3)
#
#
# appended consumpinit_scoe_tj_per_mmmgdp_commercial_municipal_heat_energy
# (26387, 2)
# (26387, 617)
# (26387, 3)
#
#
# appended consumpinit_scoe_tj_per_mmmgdp_other_se_heat_energy
# (26387, 2)
# (26387, 618)
# (26387, 3)
#
#
# appended consumpinit_scoe_gj_per_hh_residential_elec_appliances
# (26387, 2)
# (26387, 619)
# (26387, 3)
#
#
# appended consumpinit_scoe_gj_per_hh_residential_heat_energy
# (26387, 2)
# (26387, 620)
# (26387, 3)
#
#
# appended avgload_trns_freight_tonne_per_vehicle_rail_freight
# (26387, 2)
# (26387, 621)
# (26387, 3)
#
#
# appended avgload_trns_freight_tonne_per_vehicle_road_heavy_freight
# (26387, 2)
# (26387, 622)
# (26387, 3)
#
#
# appended avgload_trns_freight_tonne_per_vehicle_water_borne
# (26387, 2)
# (26387, 623)
# (26387, 3)
#
#
# appended occrate_trns_passenger_per_vehicle_aviation
# (27269, 2)
# (27269, 624)
# (27269, 3)
#
#
# appended occrate_trns_passenger_per_vehicle_public
# (27269, 2)
# (27269, 625)
# (27269, 3)
#
#
# appended occrate_trns_passenger_per_vehicle_rail_passenger
# (27269, 2)
# (27269, 626)
# (27269, 3)
#
#
# appended occrate_trns_passenger_per_vehicle_road_heavy_regional
# (27269, 2)
# (27269, 627)
# (27269, 3)
#
#
# appended occrate_trns_passenger_per_vehicle_road_light
# (27269, 2)
# (27269, 628)
# (27269, 3)
#
#
# appended elecfuelefficiency_trns_rail_freight_km_per_kwh
# (27269, 2)
# (27269, 629)
# (27269, 3)
#
#
# appended elecfuelefficiency_trns_rail_passenger_km_per_kwh
# (27269, 2)
# (27269, 630)
# (27269, 3)
#
#
# appended frac_trns_mtkm_dem_freight_aviation
# (27269, 2)
# (27269, 631)
# (27269, 3)
#
#
# appended frac_trns_mtkm_dem_freight_rail_freight
# (27269, 2)
# (27269, 632)
# (27269, 3)
#
#
# appended frac_trns_mtkm_dem_freight_road_heavy_freight
# (27269, 2)
# (27269, 633)
# (27269, 3)
#
#
# appended frac_trns_mtkm_dem_freight_water_borne
# (27269, 2)
# (27269, 634)
# (27269, 3)
#
#
# appended fuelefficiency_trns_public_biofuels_km_per_litre
# (27269, 2)
# (27269, 635)
# (27269, 3)
#
#
# appended fuelefficiency_trns_road_heavy_freight_biofuels_km_per_litre
# (27269, 2)
# (27269, 636)
# (27269, 3)
#
#
# appended fuelefficiency_trns_road_heavy_regional_biofuels_km_per_litre
# (27269, 2)
# (27269, 637)
# (27269, 3)
#
#
# appended fuelefficiency_trns_road_light_biofuels_km_per_litre
# (27269, 2)
# (27269, 638)
# (27269, 3)
#
#
# appended fuelefficiency_trns_public_diesel_km_per_litre
# (27269, 2)
# (27269, 639)
# (27269, 3)
#
#
# appended fuelefficiency_trns_rail_freight_diesel_km_per_litre
# (27269, 2)
# (27269, 640)
# (27269, 3)
#
#
# appended fuelefficiency_trns_rail_passenger_diesel_km_per_litre
# (27269, 2)
# (27269, 641)
# (27269, 3)
#
#
# appended fuelefficiency_trns_road_heavy_freight_diesel_km_per_litre
# (27269, 2)
# (27269, 642)
# (27269, 3)
#
#
# appended fuelefficiency_trns_road_heavy_regional_diesel_km_per_litre
# (27269, 2)
# (27269, 643)
# (27269, 3)
#
#
# appended fuelefficiency_trns_road_light_diesel_km_per_litre
# (27269, 2)
# (27269, 644)
# (27269, 3)
#
#
# appended fuelefficiency_trns_water_borne_diesel_km_per_litre
# (27269, 2)
# (27269, 645)
# (27269, 3)
#
#
# appended fuelefficiency_trns_powered_bikes_gasoline_km_per_litre
# (27269, 2)
# (27269, 646)
# (27269, 3)
#
#
# appended fuelefficiency_trns_public_gasoline_km_per_litre
# (27269, 2)
# (27269, 647)
# (27269, 3)
#
#
# appended fuelefficiency_trns_road_heavy_freight_gasoline_km_per_litre
# (27269, 2)
# (27269, 648)
# (27269, 3)
#
#
# appended fuelefficiency_trns_road_heavy_regional_gasoline_km_per_litre
# (27269, 2)
# (27269, 649)
# (27269, 3)
#
#
# appended fuelefficiency_trns_road_light_gasoline_km_per_litre
# (27269, 2)
# (27269, 650)
# (27269, 3)
#
#
# appended fuelefficiency_trns_aviation_hydrogen_km_per_litre
# (27269, 2)
# (27269, 651)
# (27269, 3)
#
#
# appended fuelefficiency_trns_public_hydrogen_km_per_litre
# (27269, 2)
# (27269, 652)
# (27269, 3)
#
#
# appended fuelefficiency_trns_rail_freight_hydrogen_km_per_litre
# (27269, 2)
# (27269, 653)
# (27269, 3)
#
#
# appended fuelefficiency_trns_rail_passenger_hydrogen_km_per_litre
# (27269, 2)
# (27269, 654)
# (27269, 3)
#
#
# appended fuelefficiency_trns_road_heavy_freight_hydrogen_km_per_litre
# (27269, 2)
# (27269, 655)
# (27269, 3)
#
#
# appended fuelefficiency_trns_road_heavy_regional_hydrogen_km_per_litre
# (27269, 2)
# (27269, 656)
# (27269, 3)
#
#
# appended fuelefficiency_trns_road_light_hydrogen_km_per_litre
# (27269, 2)
# (27269, 657)
# (27269, 3)
#
#
# appended fuelefficiency_trns_water_borne_hydrogen_km_per_litre
# (27269, 2)
# (27269, 658)
# (27269, 3)
#
#
# appended fuelefficiency_trns_aviation_kerosene_km_per_litre
# (27269, 2)
# (27269, 659)
# (27269, 3)
#
#
# appended fuelefficiency_trns_public_natural_gas_km_per_litre
# (27269, 2)
# (27269, 660)
# (27269, 3)
#
#
# appended fuelefficiency_trns_rail_freight_natural_gas_km_per_litre
# (27269, 2)
# (27269, 661)
# (27269, 3)
#
#
# appended fuelefficiency_trns_rail_passenger_natural_gas_km_per_litre
# (27269, 2)
# (27269, 662)
# (27269, 3)
#
#
# appended fuelefficiency_trns_road_heavy_freight_natural_gas_km_per_litre
# (27269, 2)
# (27269, 663)
# (27269, 3)
#
#
# appended fuelefficiency_trns_road_heavy_regional_natural_gas_km_per_litre
# (27269, 2)
# (27269, 664)
# (27269, 3)
#
#
# appended fuelefficiency_trns_water_borne_natural_gas_km_per_litre
# (27269, 2)
# (27269, 665)
# (27269, 3)
#
#
# appended frac_trns_pkm_dem_private_and_public_human_powered
# (27269, 2)
# (27269, 666)
# (27269, 3)
#
#
# appended frac_trns_pkm_dem_private_and_public_powered_bikes
# (27269, 2)
# (27269, 667)
# (27269, 3)
#
#
# appended frac_trns_pkm_dem_private_and_public_public
# (27269, 2)
# (27269, 668)
# (27269, 3)
#
#
# appended frac_trns_pkm_dem_private_and_public_road_light
# (27269, 2)
# (27269, 669)
# (27269, 3)
#
#
# appended frac_trns_pkm_dem_regional_aviation
# (27269, 2)
# (27269, 670)
# (27269, 3)
#
#
# appended frac_trns_pkm_dem_regional_rail_passenger
# (27269, 2)
# (27269, 671)
# (27269, 3)
#
#
# appended frac_trns_pkm_dem_regional_road_heavy_regional
# (27269, 2)
# (27269, 672)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_public_biofuels
# (27269, 2)
# (27269, 673)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_road_heavy_freight_biofuels
# (27269, 2)
# (27269, 674)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_road_heavy_regional_biofuels
# (27269, 2)
# (27269, 675)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_road_light_biofuels
# (27269, 2)
# (27269, 676)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_public_diesel
# (27269, 2)
# (27269, 677)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_rail_freight_diesel
# (27269, 2)
# (27269, 678)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_rail_passenger_diesel
# (27269, 2)
# (27269, 679)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_road_heavy_freight_diesel
# (27269, 2)
# (27269, 680)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_road_heavy_regional_diesel
# (27269, 2)
# (27269, 681)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_road_light_diesel
# (27269, 2)
# (27269, 682)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_water_borne_diesel
# (27269, 2)
# (27269, 683)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_aviation_electricity
# (27269, 2)
# (27269, 684)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_powered_bikes_electricity
# (27269, 2)
# (27269, 685)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_public_electricity
# (27269, 2)
# (27269, 686)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_rail_freight_electricity
# (27269, 2)
# (27269, 687)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_rail_passenger_electricity
# (27269, 2)
# (27269, 688)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_road_heavy_freight_electricity
# (27269, 2)
# (27269, 689)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_road_heavy_regional_electricity
# (27269, 2)
# (27269, 690)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_road_light_electricity
# (27269, 2)
# (27269, 691)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_water_borne_electricity
# (27269, 2)
# (27269, 692)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_powered_bikes_gasoline
# (27269, 2)
# (27269, 693)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_public_gasoline
# (27269, 2)
# (27269, 694)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_road_heavy_freight_gasoline
# (27269, 2)
# (27269, 695)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_road_heavy_regional_gasoline
# (27269, 2)
# (27269, 696)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_road_light_gasoline
# (27269, 2)
# (27269, 697)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_aviation_hydrogen
# (27269, 2)
# (27269, 698)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_public_hydrogen
# (27269, 2)
# (27269, 699)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_rail_freight_hydrogen
# (27269, 2)
# (27269, 700)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_rail_passenger_hydrogen
# (27269, 2)
# (27269, 701)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_road_heavy_freight_hydrogen
# (27269, 2)
# (27269, 702)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_road_heavy_regional_hydrogen
# (27269, 2)
# (27269, 703)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_road_light_hydrogen
# (27269, 2)
# (27269, 704)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_water_borne_hydrogen
# (27269, 2)
# (27269, 705)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_aviation_kerosene
# (27269, 2)
# (27269, 706)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_public_natural_gas
# (27269, 2)
# (27269, 707)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_rail_freight_natural_gas
# (27269, 2)
# (27269, 708)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_rail_passenger_natural_gas
# (27269, 2)
# (27269, 709)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_road_heavy_freight_natural_gas
# (27269, 2)
# (27269, 710)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_road_heavy_regional_natural_gas
# (27269, 2)
# (27269, 711)
# (27269, 3)
#
#
# appended frac_trns_fuelmix_water_borne_natural_gas
# (27269, 2)
# (27269, 712)
# (27269, 3)
#
#
# appended deminit_trde_freight_mt_km
# (27269, 2)
# (27269, 713)
# (27269, 3)
#
#
# appended deminit_trde_private_and_public_per_capita_passenger_km
# (27269, 2)
# (27269, 714)
# (27269, 3)
#
#
# appended deminit_trde_regional_per_capita_passenger_km
# (27269, 2)
# (27269, 715)
# (27269, 3)
#
#
# here
# 348.05

# %%
df_complete.drop(["index"], axis = 1, inplace = True) if ("index" in df_complete.columns) else None
df_complete["year"] = df_complete["year"].astype(int)
df_complete = df_complete[~df_complete["iso_code3"].isna()]
df_complete = df_complete[~df_complete["frac_agrc_bevs_and_spices_cl2_dry"].isna()].reset_index(drop = True)

# %%
#df_complete.dropna()
df2020 = df_complete[df_complete["year"].isin([2020])]
df20202 = df2020[["iso_code3", "year"] + [x for x in df2020.columns if "scoe" in x]]

check = df20202[df20202["iso_code3"].isin(["CHL"])]

for x in check.columns:
    if len(check[x].dropna()) == 0:
        print(x)

# %%
fields_index = ["iso_code3", "year"]
#df_var[1].set_index(fields_index, inplace = True)

# %%
df_var_cur = df_var[1]

# %%
df_var = pd.concat(df_var, axis = 0) if (len(df_var) > 0) else None

# %%
#df_var[["iso_code3", "year"]]

# %%
inds_prev = df_var[0].index

# %%
fp_read2 = "/Users/jsyme/Documents/Projects/git_jbus/sisepuede_data/IPPU/net_imports_cement_clinker_tonne/input_to_sisepuede/historical/net_imports_cement_clinker_tonne.csv"

fp_read == fp_read2
# Out:
# False

# %%
df = pd.read_csv(fp_read)
dict_rnm = dict((x, x.lower()) for x in df.columns)
df.rename(columns = dict_rnm, inplace = True)
df[fields_index].drop_duplicates().shape# == df[fields_index].shape
# Out:
# (5431, 2)

# %%
df = pd.read_csv(fp_read)
df[
    df["iso_code3"].isin(["EGY"]) 
    & df["Year"].isin([2019])
]
# Out:
#       Year            Nation iso_code3  population_gnrl_urban
# 1768  2019  Egypt, Arab Rep.       EGY           3.996680e+07

# %%
fp_read_2 = '/Users/jsyme/Documents/Projects/git_jbus/sisepuede_data/SocioEconomic/population_gnrl_urban/input_to_sisepuede/historical/population_gnrl_urban.csv'
df_2 = pd.read_csv(fp_read_2)
df_2[
    df_2["iso_code3"].isin(["EGY"]) 
    & df_2["Year"].isin([2019])
]
# Out:
#       Year            Nation iso_code3  population_gnrl_urban
# 1505  2019  Egypt, Arab Rep.       EGY           4.289582e+07

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[106], line 3
#       1 dir_repo_data = "/Users/jsyme/Documents/Projects/git_jbus/sisepuede_data"
# ----> 3 df, dict_modvar_to_fields, dict_modvar_to_ordered_cats = read_inputs_from_repository(dir_repo_data, None, sa.model_attributes)
#
# Cell In[105], line 178, in read_inputs_from_repository(dir_repo_data, dict_modvars, model_attributes, field_iso, field_year, fields_drop, fields_index, fields_to_iso, regions, time_periods)
#     167                 (
#     168                     dict_modvar_to_ordered_cats.update({modvar: [cat]})
#     169                     if fields_exist is None
#     170                     else dict_modvar_to_ordered_cats[modvar].append(cat)
#     171                 )
#     174             if df_var is not None:
#     175                 df_out = (
#     176                     df_var
#     177                     if (df_out is None)
# --> 178                     else pd.merge(df_out, df_var, how = "outer", on = fields_index)
#     179                 )
#     181 if (df_out is not None) and (fields_index is not None):
#     182     df_out.sort_values(by = fields_index, inplace = True)
#
# File ~/anaconda3/envs/amber_is_your_energy/lib/python3.11/site-packages/pandas/core/reshape/merge.py:124, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
#     110     op = _MergeOperation(
#     111         left,
#     112         right,
#    (...)
#     122         validate=validate,
#     123     )
# --> 124     return op.get_result(copy=copy)
#
# File ~/anaconda3/envs/amber_is_your_energy/lib/python3.11/site-packages/pandas/core/reshape/merge.py:775, in _MergeOperation.get_result(self, copy)
#     771     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     773 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 775 result = self._reindex_and_concat(
#     776     join_index, left_indexer, right_indexer, copy=copy
#     777 )
#     778 result = result.__finalize__(self, method=self._merge_type)
#     780 if self.indicator:
#
# File ~/anaconda3/envs/amber_is_your_energy/lib/python3.11/site-packages/pandas/core/reshape/merge.py:737, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     729 llabels, rlabels = _items_overlap_with_suffix(
#     730     self.left._info_axis, self.right._info_axis, self.suffixes
#     731 )
#     733 if left_indexer is not None:
#     734     # Pinning the index here (and in the right code just below) is not
#     735     #  necessary, but makes the `.take` more performant if we have e.g.
#     736     #  a MultiIndex for left.index.
# --> 737     lmgr = left._mgr.reindex_indexer(
#     738         join_index,
#     739         left_indexer,
#     740         axis=1,
#     741         copy=False,
#     742         only_slice=True,
#     743         allow_dups=True,
#     744         use_na_proxy=True,
#     745     )
#     746     left = left._constructor(lmgr)
#     747 left.index = join_index
#
# File ~/anaconda3/envs/amber_is_your_energy/lib/python3.11/site-packages/pandas/core/internals/managers.py:753, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     751     parent = None if com.all_none(*new_refs) else self
#     752 else:
# --> 753     new_blocks = [
#     754         blk.take_nd(
#     755             indexer,
#     756             axis=1,
#     757             fill_value=(
#     758                 fill_value if fill_value is not None else blk.fill_value
#     759             ),
#     760         )
#     761         for blk in self.blocks
#     762     ]
#     763     new_refs = None
#     764     parent = None
#
# File ~/anaconda3/envs/amber_is_your_energy/lib/python3.11/site-packages/pandas/core/internals/managers.py:754, in <listcomp>(.0)
#     751     parent = None if com.all_none(*new_refs) else self
#     752 else:
#     753     new_blocks = [
# --> 754         blk.take_nd(
#     755             indexer,
#     756             axis=1,
#     757             fill_value=(
#     758                 fill_value if fill_value is not None else blk.fill_value
#     759             ),
#     760         )
#     761         for blk in self.blocks
#     762     ]
#     763     new_refs = None
#     764     parent = None
#
# File ~/anaconda3/envs/amber_is_your_energy/lib/python3.11/site-packages/pandas/core/internals/blocks.py:880, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#     877     allow_fill = True
#     879 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# --> 880 new_values = algos.take_nd(
#     881     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#     882 )
#     884 # Called from three places in managers, all of which satisfy
#     885 #  this assertion
#     886 assert not (axis == 0 and new_mgr_locs is None)
#
# File ~/anaconda3/envs/amber_is_your_energy/lib/python3.11/site-packages/pandas/core/array_algos/take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~/anaconda3/envs/amber_is_your_energy/lib/python3.11/site-packages/pandas/core/array_algos/take.py:163, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     158     out = np.empty(out_shape, dtype=dtype)
#     160 func = _get_take_nd_function(
#     161     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     162 )
# --> 163 func(arr, indexer, out, fill_value)
#     165 if flip_order:
#     166     out = out.T
#
# KeyboardInterrupt:

# %%
df2020 = df[df["year"] == 2020]
vals = []
for k in df.columns:
    tt = len(df[k].dropna())
    
    if tt < len(df):
        vals.append(k)
df[df[vals[0]].isna()]["iso_code3"].unique()

# %%
df[
    df["yf_agrc_rice_tonne_ha"].isna()
]
# Out:
#       year iso_code3  frac_agrc_bevs_and_spices_cl2_dry  \
# 0     2010       ABW                           1.000000
# 1     2010       AFG                           0.994548
# 2     2010       AGO                           0.615825
# 3     2010       ALB                           0.320181
# 4     2010       AND                           0.117647
# ...    ...       ...                                ...
# 9058  2050       SXM                           0.000000
# 9061  2050       TCA                           0.086397
# 9072  2050       TUR                           0.887015
# 9084  2050       VGB                           0.000000
# 9085  2050       VIR                           0.000000
#
#       frac_agrc_cereals_cl2_dry  frac_agrc_fibers_cl2_dry  \
# 0                      1.000000                  1.000000
# 1                      0.994548                  0.994548
# 2                      0.615825                  0.615825
# 3                      0.320181                  0.320181
# 4                      0.117647                  0.117647
# ...                         ...                       ...
# 9058                   0.000000                  0.000000
# 9061                   0.086397                  0.086397
# 9072                   0.887015                  0.887015
# 9084                   0.000000                  0.000000
# 9085                   0.000000                  0.000000
#
#       frac_agrc_fruits_cl2_dry  \
# 0                     1.000000
# 1                     0.994548
# 2                     0.615825
# 3                     0.320181
# 4                     0.117647
# ...                        ...
# 9058                  0.000000
# 9061                  0.086397
# 9072                  0.887015
# 9084                  0.000000
# 9085                  0.000000
#
#       frac_agrc_herbs_and_other_perennial_crops_cl2_dry  \
# 0                                              1.000000
# 1                                              0.994548
# 2                                              0.615825
# 3                                              0.320181
# 4                                              0.117647
# ...                                                 ...
# 9058                                           0.000000
# 9061                                           0.086397
# 9072                                           0.887015
# 9084                                           0.000000
# 9085                                           0.000000
#
#       frac_agrc_nuts_cl2_dry  frac_agrc_other_annual_cl2_dry  \
# 0                   1.000000                        1.000000
# 1                   0.994548                        0.994548
# 2                   0.615825                        0.615825
# 3                   0.320181                        0.320181
# 4                   0.117647                        0.117647
# ...                      ...                             ...
# 9058                0.000000                        0.000000
# 9061                0.086397                        0.086397
# 9072                0.887015                        0.887015
# 9084                0.000000                        0.000000
# 9085                0.000000                        0.000000
#
#       frac_agrc_other_woody_perennial_cl2_dry  ...  yf_agrc_fruits_tonne_ha  \
# 0                                    1.000000  ...                      NaN
# 1                                    0.994548  ...                      NaN
# 2                                    0.615825  ...                      NaN
# 3                                    0.320181  ...                      NaN
# 4                                    0.117647  ...                      NaN
# ...                                       ...  ...                      ...
# 9058                                 0.000000  ...                      NaN
# 9061                                 0.086397  ...                      NaN
# 9072                                 0.887015  ...                      NaN
# 9084                                 0.000000  ...                      NaN
# 9085                                 0.000000  ...                      NaN
#
#       yf_agrc_herbs_and_other_perennial_crops_tonne_ha  yf_agrc_nuts_tonne_ha  \
# 0                                                  NaN                    NaN
# 1                                                  NaN                    NaN
# 2                                                  NaN                    NaN
# 3                                                  NaN                    NaN
# 4                                                  NaN                    NaN
# ...                                                ...                    ...
# 9058                                               NaN                    NaN
# 9061                                               NaN                    NaN
# 9072                                               NaN                    NaN
# 9084                                               NaN                    NaN
# 9085                                               NaN                    NaN
#
#       yf_agrc_other_annual_tonne_ha  yf_agrc_other_woody_perennial_tonne_ha  \
# 0                               NaN                                     NaN
# 1                               NaN                                     NaN
# 2                               NaN                                     NaN
# 3                               NaN                                     NaN
# 4                               NaN                                     NaN
# ...                             ...                                     ...
# 9058                            NaN                                     NaN
# 9061                            NaN                                     NaN
# 9072                            NaN                                     NaN
# 9084                            NaN                                     NaN
# 9085                            NaN                                     NaN
#
#       yf_agrc_pulses_tonne_ha  yf_agrc_rice_tonne_ha  \
# 0                         NaN                    NaN
# 1                         NaN                    NaN
# 2                         NaN                    NaN
# 3                         NaN                    NaN
# 4                         NaN                    NaN
# ...                       ...                    ...
# 9058                      NaN                    NaN
# 9061                      NaN                    NaN
# 9072                      NaN                    NaN
# 9084                      NaN                    NaN
# 9085                      NaN                    NaN
#
#       yf_agrc_sugar_cane_tonne_ha  yf_agrc_tubers_tonne_ha  \
# 0                             NaN                      NaN
# 1                             NaN                      NaN
# 2                             NaN                      NaN
# 3                             NaN                      NaN
# 4                             NaN                      NaN
# ...                           ...                      ...
# 9058                          NaN                      NaN
# 9061                          NaN                      NaN
# 9072                          NaN                      NaN
# 9084                          NaN                      NaN
# 9085                          NaN                      NaN
#
#       yf_agrc_vegetables_and_vines_tonne_ha
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 9058                                    NaN
# 9061                                    NaN
# 9072                                    NaN
# 9084                                    NaN
# 9085                                    NaN
#
# [1094 rows x 67 columns]

# %%
df_clim = pd.read_csv("/Users/jsyme/Documents/Projects/git_jbus/lac_decarbonization/ref/batch_data_generation/koppen_climate_classifications/climate_fields_by_country.csv")

# %%
df_clim[df_clim["iso_alpha_3"].isin(["FRA"])]
# Out:
# Empty DataFrame
# Columns: [iso_alpha_3, time_period, year, frac_agrc_bevs_and_spices_cl1_temperate, frac_agrc_bevs_and_spices_cl1_tropical, frac_agrc_bevs_and_spices_cl2_dry, frac_agrc_bevs_and_spices_cl2_wet, frac_agrc_cereals_cl1_temperate, frac_agrc_cereals_cl1_tropical, frac_agrc_cereals_cl2_dry, frac_agrc_cereals_cl2_wet, frac_agrc_fibers_cl1_temperate, frac_agrc_fibers_cl1_tropical, frac_agrc_fibers_cl2_dry, frac_agrc_fibers_cl2_wet, frac_agrc_fruits_cl1_temperate, frac_agrc_fruits_cl1_tropical, frac_agrc_fruits_cl2_dry, frac_agrc_fruits_cl2_wet, frac_agrc_herbs_and_other_perennial_crops_cl1_temperate, frac_agrc_herbs_and_other_perennial_crops_cl1_tropical, frac_agrc_herbs_and_other_perennial_crops_cl2_dry, frac_agrc_herbs_and_other_perennial_crops_cl2_wet, frac_agrc_nuts_cl1_temperate, frac_agrc_nuts_cl1_tropical, frac_agrc_nuts_cl2_dry, frac_agrc_nuts_cl2_wet, frac_agrc_other_annual_cl1_temperate, frac_agrc_other_annual_cl1_tropical, frac_agrc_other_annual_cl2_dry, frac_agrc_other_annual_cl2_wet, frac_agrc_other_woody_perennial_cl1_temperate, frac_agrc_other_woody_perennial_cl1_tropical, frac_agrc_other_woody_perennial_cl2_dry, frac_agrc_other_woody_perennial_cl2_wet, frac_agrc_pulses_cl1_temperate, frac_agrc_pulses_cl1_tropical, frac_agrc_pulses_cl2_dry, frac_agrc_pulses_cl2_wet, frac_agrc_rice_cl1_temperate, frac_agrc_rice_cl1_tropical, frac_agrc_rice_cl2_dry, frac_agrc_rice_cl2_wet, frac_agrc_sugar_cane_cl1_temperate, frac_agrc_sugar_cane_cl1_tropical, frac_agrc_sugar_cane_cl2_dry, frac_agrc_sugar_cane_cl2_wet, frac_agrc_tubers_cl1_temperate, frac_agrc_tubers_cl1_tropical, frac_agrc_tubers_cl2_dry, frac_agrc_tubers_cl2_wet, frac_agrc_vegetables_and_vines_cl1_temperate, frac_agrc_vegetables_and_vines_cl1_tropical, frac_agrc_vegetables_and_vines_cl2_dry, frac_agrc_vegetables_and_vines_cl2_wet, frac_frst_mangroves_cl1_temperate_nutrient_poor, frac_frst_mangroves_cl1_temperate_nutrient_rich, frac_frst_mangroves_cl1_tropical, frac_frst_primary_cl1_temperate_nutrient_poor, frac_frst_primary_cl1_temperate_nutrient_rich, frac_frst_primary_cl1_tropical, frac_frst_secondary_cl1_temperate_nutrient_poor, frac_frst_secondary_cl1_temperate_nutrient_rich, frac_frst_secondary_cl1_tropical, frac_lndu_grasslands_cl1_temperate, frac_lndu_grasslands_cl1_tropical, frac_lndu_grasslands_cl2_dry, frac_lndu_grasslands_cl2_wet, frac_lndu_other_cl2_dry, frac_lndu_other_cl2_wet, frac_lndu_settlements_cl2_dry, frac_lndu_settlements_cl2_wet]
# Index: []
#
# [0 rows x 72 columns]

# %%
df_clim["iso_alpha_3"].unique()
# Out:
# array(['ABW', 'AFG', 'AGO', 'ALB', 'AND', 'ARE', 'ARG', 'ARM', 'ASM',
#        'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BFA', 'BGD',
#        'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU', 'BOL', 'BRA',
#        'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CHE', 'CHL', 'CHN',
#        'CIV', 'CMR', 'COD', 'COG', 'COL', 'COM', 'CPV', 'CRI', 'CUB',
#        'CUW', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI', 'DMA', 'DNK', 'DOM',
#        'DZA', 'ECU', 'EGY', 'ERI', 'ESP', 'EST', 'ETH', 'FIN', 'FJI',
#        'FRO', 'FSM', 'GAB', 'GBR', 'GEO', 'GHA', 'GIB', 'GIN', 'GMB',
#        'GNB', 'GNQ', 'GRC', 'GRD', 'GRL', 'GTM', 'GUM', 'GUY', 'HKG',
#        'HND', 'HRV', 'HTI', 'HUN', 'IDN', 'IMN', 'IND', 'IRL', 'IRN',
#        'IRQ', 'ISL', 'ISR', 'ITA', 'JAM', 'JOR', 'JPN', 'KAZ', 'KEN',
#        'KGZ', 'KHM', 'KIR', 'KNA', 'KOR', 'KWT', 'LAO', 'LBN', 'LBR',
#        'LBY', 'LCA', 'LIE', 'LKA', 'LSO', 'LTU', 'LUX', 'LVA', 'MAC',
#        'MAF', 'MAR', 'MCO', 'MDA', 'MDG', 'MDV', 'MEX', 'MHL', 'MKD',
#        'MLI', 'MLT', 'MMR', 'MNE', 'MNG', 'MNP', 'MOZ', 'MRT', 'MUS',
#        'MWI', 'MYS', 'NAM', 'NCL', 'NER', 'NGA', 'NIC', 'NLD', 'NPL',
#        'NRU', 'NZL', 'OMN', 'PAK', 'PAN', 'PER', 'PHL', 'PLW', 'PNG',
#        'POL', 'PRI', 'PRK', 'PRT', 'PRY', 'PYF', 'QAT', 'ROU', 'RUS',
#        'RWA', 'SAU', 'SDN', 'SEN', 'SGP', 'SLB', 'SLE', 'SLV', 'SMR',
#        'SOM', 'SRB', 'SSD', 'STP', 'SUR', 'SVK', 'SVN', 'SWE', 'SWZ',
#        'SXM', 'SYC', 'SYR', 'TCA', 'TCD', 'TGO', 'THA', 'TJK', 'TKM',
#        'TLS', 'TON', 'TTO', 'TUN', 'TUR', 'TUV', 'TZA', 'UGA', 'UKR',
#        'URY', 'USA', 'UZB', 'VCT', 'VEN', 'VGB', 'VIR', 'VNM', 'VUT',
#        'WSM', 'YEM', 'ZAF', 'ZMB', 'ZWE'], dtype=object)
